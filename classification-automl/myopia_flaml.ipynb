# %%
# !python --version
# Out:
# Python 3.7.13

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ----------------------------
# absl-py                       1.2.0
# aeppl                         0.0.33
# aesara                        2.7.9
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# albumentations                1.2.1
# altair                        4.2.0
# appdirs                       1.4.4
# arviz                         0.12.1
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# async-timeout                 4.0.2
# asynctest                     0.13.0
# atari-py                      0.2.9
# atomicwrites                  1.4.1
# attrs                         22.1.0
# audioread                     3.0.0
# autograd                      1.4
# Babel                         2.10.3
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        5.0.1
# blis                          0.7.8
# bokeh                         2.3.3
# branca                        0.5.0
# bs4                           0.0.1
# CacheControl                  0.12.11
# cached-property               1.5.2
# cachetools                    4.2.4
# catalogue                     2.0.8
# certifi                       2022.6.15
# cffi                          1.15.1
# cftime                        1.6.1
# chardet                       3.0.4
# charset-normalizer            2.1.1
# click                         7.1.2
# clikit                        0.6.2
# cloudpickle                   1.5.0
# cmake                         3.22.6
# cmdstanpy                     1.0.7
# colorcet                      3.0.0
# colorlover                    0.3.0
# community                     1.0.0b1
# cons                          0.4.5
# contextlib2                   0.5.5
# convertdate                   2.4.0
# crashtest                     0.3.1
# crcmod                        1.7
# cufflinks                     0.17.3
# cvxopt                        1.3.0
# cvxpy                         1.2.1
# cycler                        0.11.0
# cymem                         2.0.6
# Cython                        0.29.32
# daft                          0.0.4
# dask                          2022.2.0
# datascience                   0.17.5
# debugpy                       1.0.0
# decorator                     4.4.2
# defusedxml                    0.7.1
# descartes                     1.1.0
# dill                          0.3.5.1
# distributed                   2022.2.0
# dlib                          19.24.0
# dm-tree                       0.1.7
# docutils                      0.17.1
# dopamine-rl                   1.0.5
# earthengine-api               0.1.321
# easydict                      1.9
# ecos                          2.0.10
# editdistance                  0.5.3
# en-core-web-sm                3.4.0
# entrypoints                   0.4
# ephem                         4.1.3
# et-xmlfile                    1.1.0
# etils                         0.7.1
# etuples                       0.3.5
# fa2                           0.3.5
# fastai                        2.7.9
# fastcore                      1.5.22
# fastdownload                  0.0.7
# fastdtw                       0.3.4
# fastjsonschema                2.16.1
# fastprogress                  1.0.3
# fastrlock                     0.8
# feather-format                0.4.1
# filelock                      3.8.0
# firebase-admin                4.4.0
# fix-yahoo-finance             0.0.22
# Flask                         1.1.4
# flatbuffers                   2.0.7
# folium                        0.12.1.post1
# frozenlist                    1.3.1
# fsspec                        2022.7.1
# future                        0.16.0
# gast                          0.5.3
# GDAL                          2.2.2
# gdown                         4.4.0
# gensim                        3.6.0
# geographiclib                 1.52
# geopy                         1.17.0
# gin-config                    0.5.0
# glob2                         0.7
# google                        2.0.3
# google-api-core               1.31.6
# google-api-python-client      1.12.11
# google-auth                   1.35.0
# google-auth-httplib2          0.0.4
# google-auth-oauthlib          0.4.6
# google-cloud-bigquery         1.21.0
# google-cloud-bigquery-storage 1.1.2
# google-cloud-core             1.0.3
# google-cloud-datastore        1.8.0
# google-cloud-firestore        1.7.0
# google-cloud-language         1.2.0
# google-cloud-storage          1.18.1
# google-cloud-translate        1.5.0
# google-colab                  1.0.0
# google-pasta                  0.2.0
# google-resumable-media        0.4.1
# googleapis-common-protos      1.56.4
# googledrivedownloader         0.4
# graphviz                      0.10.1
# greenlet                      1.1.3
# grpcio                        1.47.0
# gspread                       3.4.2
# gspread-dataframe             3.0.8
# gym                           0.25.2
# gym-notices                   0.0.8
# h5py                          3.1.0
# HeapDict                      1.0.1
# hijri-converter               2.2.4
# holidays                      0.15
# holoviews                     1.14.9
# html5lib                      1.0.1
# httpimport                    0.5.18
# httplib2                      0.17.4
# httplib2shim                  0.0.3
# httpstan                      4.6.1
# humanize                      0.5.1
# hyperopt                      0.1.2
# idna                          2.10
# imageio                       2.9.0
# imagesize                     1.4.1
# imbalanced-learn              0.8.1
# imblearn                      0.0
# imgaug                        0.4.0
# importlib-metadata            4.12.0
# importlib-resources           5.9.0
# imutils                       0.5.4
# inflect                       2.1.0
# intel-openmp                  2022.1.0
# intervaltree                  2.1.0
# ipykernel                     5.3.4
# ipython                       7.9.0
# ipython-genutils              0.2.0
# ipython-sql                   0.3.9
# ipywidgets                    7.7.1
# itsdangerous                  1.1.0
# jax                           0.3.14
# jaxlib                        0.3.14+cuda11.cudnn805
# jieba                         0.42.1
# Jinja2                        2.11.3
# joblib                        1.1.0
# jpeg4py                       0.1.4
# jsonschema                    4.3.3
# jupyter-client                6.1.12
# jupyter-console               6.1.0
# jupyter-core                  4.11.1
# jupyterlab-widgets            3.0.2
# kaggle                        1.5.12
# kapre                         0.3.7
# keras                         2.8.0
# Keras-Preprocessing           1.1.2
# keras-vis                     0.4.1
# kiwisolver                    1.4.4
# korean-lunar-calendar         0.2.1
# langcodes                     3.3.0
# libclang                      14.0.6
# librosa                       0.8.1
# lightgbm                      2.2.3
# llvmlite                      0.39.0
# lmdb                          0.99
# locket                        1.0.0
# logical-unification           0.4.5
# LunarCalendar                 0.0.9
# lxml                          4.9.1
# Markdown                      3.4.1
# MarkupSafe                    2.0.1
# marshmallow                   3.17.1
# matplotlib                    3.2.2
# matplotlib-venn               0.11.7
# miniKanren                    1.0.3
# missingno                     0.5.1
# mistune                       0.8.4
# mizani                        0.7.3
# mkl                           2019.0
# mlxtend                       0.14.0
# more-itertools                8.14.0
# moviepy                       0.2.3.5
# mpmath                        1.2.1
# msgpack                       1.0.4
# multidict                     6.0.2
# multipledispatch              0.6.0
# multitasking                  0.0.11
# murmurhash                    1.0.8
# music21                       5.5.0
# natsort                       5.5.0
# nbconvert                     5.6.1
# nbformat                      5.4.0
# netCDF4                       1.6.0
# networkx                      2.6.3
# nibabel                       3.0.2
# nltk                          3.7
# notebook                      5.3.1
# numba                         0.56.0
# numexpr                       2.8.3
# numpy                         1.21.6
# oauth2client                  4.1.3
# oauthlib                      3.2.0
# okgrade                       0.4.3
# opencv-contrib-python         4.6.0.66
# opencv-python                 4.6.0.66
# opencv-python-headless        4.6.0.66
# openpyxl                      3.0.10
# opt-einsum                    3.3.0
# osqp                          0.6.2.post0
# packaging                     21.3
# palettable                    3.3.0
# pandas                        1.3.5
# pandas-datareader             0.9.0
# pandas-gbq                    0.13.3
# pandas-profiling              1.4.1
# pandocfilters                 1.5.0
# panel                         0.12.1
# param                         1.12.2
# parso                         0.8.3
# partd                         1.3.0
# pastel                        0.2.1
# pathlib                       1.0.1
# pathy                         0.6.2
# patsy                         0.5.2
# pep517                        0.13.0
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        7.1.2
# pip                           21.1.3
# pip-tools                     6.2.0
# plotly                        5.5.0
# plotnine                      0.8.0
# pluggy                        0.7.1
# pooch                         1.6.0
# portpicker                    1.3.9
# prefetch-generator            1.0.1
# preshed                       3.0.7
# prettytable                   3.4.0
# progressbar2                  3.38.0
# promise                       2.3
# prompt-toolkit                2.0.10
# prophet                       1.1
# protobuf                      3.17.3
# psutil                        5.4.8
# psycopg2                      2.9.3
# ptyprocess                    0.7.0
# py                            1.11.0
# pyarrow                       6.0.1
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.4
# pycparser                     2.21
# pyct                          0.4.8
# pydantic                      1.9.2
# pydata-google-auth            1.4.0
# pydot                         1.3.0
# pydot-ng                      2.0.0
# pydotplus                     2.0.2
# PyDrive                       1.3.1
# pyemd                         0.5.1
# pyerfa                        2.0.0.1
# Pygments                      2.6.1
# pygobject                     3.26.1
# pylev                         1.4.0
# pymc                          4.1.4
# PyMeeus                       0.5.11
# pymongo                       4.2.0
# pymystem3                     0.2.0
# PyOpenGL                      3.1.6
# pyparsing                     3.0.9
# pyrsistent                    0.18.1
# pysimdjson                    3.2.0
# pysndfile                     1.3.8
# PySocks                       1.7.1
# pystan                        3.3.0
# pytest                        3.6.4
# python-apt                    0.0.0
# python-chess                  0.23.11
# python-dateutil               2.8.2
# python-louvain                0.16
# python-slugify                6.1.2
# python-utils                  3.3.3
# pytz                          2022.2.1
# pyviz-comms                   2.2.1
# PyWavelets                    1.3.0
# PyYAML                        6.0
# pyzmq                         23.2.1
# qdldl                         0.1.5.post2
# qudida                        0.0.4
# regex                         2022.6.2
# requests                      2.23.0
# requests-oauthlib             1.3.1
# resampy                       0.4.0
# rpy2                          3.4.5
# rsa                           4.9
# scikit-image                  0.18.3
# scikit-learn                  1.0.2
# scipy                         1.7.3
# screen-resolution-extra       0.0.0
# scs                           3.2.0
# seaborn                       0.11.2
# Send2Trash                    1.8.0
# setuptools                    57.4.0
# setuptools-git                1.2
# Shapely                       1.8.4
# six                           1.15.0
# sklearn-pandas                1.8.0
# smart-open                    5.2.1
# snowballstemmer               2.2.0
# sortedcontainers              2.4.0
# SoundFile                     0.10.3.post1
# spacy                         3.4.1
# spacy-legacy                  3.0.10
# spacy-loggers                 1.0.3
# Sphinx                        1.8.6
# sphinxcontrib-serializinghtml 1.1.5
# sphinxcontrib-websupport      1.2.4
# SQLAlchemy                    1.4.40
# sqlparse                      0.4.2
# srsly                         2.4.4
# statsmodels                   0.12.2
# sympy                         1.7.1
# tables                        3.7.0
# tabulate                      0.8.10
# tblib                         1.7.0
# tenacity                      8.0.1
# tensorboard                   2.8.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.8.2+zzzcolab20220719082949
# tensorflow-datasets           4.6.0
# tensorflow-estimator          2.8.0
# tensorflow-gcs-config         2.8.0
# tensorflow-hub                0.12.0
# tensorflow-io-gcs-filesystem  0.26.0
# tensorflow-metadata           1.10.0
# tensorflow-probability        0.16.0
# termcolor                     1.1.0
# terminado                     0.13.3
# testpath                      0.6.0
# text-unidecode                1.3
# textblob                      0.15.3
# thinc                         8.1.0
# threadpoolctl                 3.1.0
# tifffile                      2021.11.2
# toml                          0.10.2
# tomli                         2.0.1
# toolz                         0.12.0
# torch                         1.12.1+cu113
# torchaudio                    0.12.1+cu113
# torchsummary                  1.5.1
# torchtext                     0.13.1
# torchvision                   0.13.1+cu113
# tornado                       5.1.1
# tqdm                          4.64.0
# traitlets                     5.1.1
# tweepy                        3.10.0
# typeguard                     2.7.1
# typer                         0.4.2
# typing-extensions             4.1.1
# tzlocal                       1.5.1
# ujson                         5.4.0
# uritemplate                   3.0.1
# urllib3                       1.24.3
# vega-datasets                 0.9.0
# wasabi                        0.10.1
# wcwidth                       0.2.5
# webargs                       8.2.0
# webencodings                  0.5.1
# Werkzeug                      1.0.1
# wheel                         0.37.1
# widgetsnbextension            3.6.1
# wordcloud                     1.8.2.2
# wrapt                         1.14.1
# xarray                        0.20.2
# xarray-einstats               0.2.2
# xgboost                       0.90
# xkit                          0.0.0
# xlrd                          1.1.0
# xlwt                          1.3.0
# yarl                          1.8.1
# yellowbrick                   1.5
# zict                          2.2.0
# zipp                          3.8.1

# %%
# !pip install flaml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting flaml
#   Downloading FLAML-1.0.11-py3-none-any.whl (205 kB)
#      |████████████████████████████████| 205 kB 4.3 MB/s
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.7/dist-packages (from flaml) (1.0.2)
# Collecting lightgbm>=2.3.1
#   Downloading lightgbm-3.3.2-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 65.9 MB/s
# Requirement already satisfied: xgboost>=0.90 in /usr/local/lib/python3.7/dist-packages (from flaml) (0.90)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.7/dist-packages (from flaml) (1.3.5)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from flaml) (1.7.3)
# Requirement already satisfied: NumPy>=1.17.0rc1 in /usr/local/lib/python3.7/dist-packages (from flaml) (1.21.6)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm>=2.3.1->flaml) (0.37.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.4->flaml) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.4->flaml) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1.4->flaml) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24->flaml) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24->flaml) (3.1.0)
# Installing collected packages: lightgbm, flaml
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
# Successfully installed flaml-1.0.11 lightgbm-3.3.2

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from flaml import AutoML

# %%
automl = AutoML()
automl_settings={
    'time_budget':300,
    'metric': 'roc_auc',
    'task':  'classification',
    'log_file_name': 'myopia.log'

}

# %%
df = pd.read_csv('../content/reduced_filtered_df.csv')

# %%
df.head(2)
# Out:
#      ACD     LT    VCD  SPORTHR  DADMY  delta_spheq  total_positive_screen  \
# 0  3.702  3.392  15.29        4      1        1.358                      8
# 1  3.462  3.514  15.52       14      0        1.929                     10
#
#    MYOPIC
# 0       0
# 1       0

# %%
X=df.drop('MYOPIC', axis=1)
y=df['MYOPIC']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, stratify=y)

# %% [markdown]
# ## Test AUTOML

# %%
automl.fit(X_train, y_train, **automl_settings)
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:flaml.automl: at 10.2s,	estimator lgbm's best error=0.1752,	best estimator lgbm's best error=0.1752
# [flaml.automl: 09-05 00:03:29] {3133} INFO - iteration 36, current learner extra_tree
# INFO:flaml.automl:iteration 36, current learner extra_tree
# [flaml.automl: 09-05 00:03:31] {3319} INFO -  at 11.8s,	estimator extra_tree's best error=0.2082,	best estimator lgbm's best error=0.1752
# INFO:flaml.automl: at 11.8s,	estimator extra_tree's best error=0.2082,	best estimator lgbm's best error=0.1752
# [flaml.automl: 09-05 00:03:31] {3133} INFO - iteration 37, current learner lgbm
# INFO:flaml.automl:iteration 37, current learner lgbm
# [flaml.automl: 09-05 00:03:31] {3319} INFO -  at 11.8s,	estimator lgbm's best error=0.1752,	best estimator lgbm's best error=0.1752
# INFO:flaml.automl: at 11.8s,	estimator lgbm's best error=0.1752,	best estimator lgbm's best error=0.1752
# [flaml.automl: 09-05 00:03:31] {3133} INFO - iteration 38, current learner rf
# INFO:flaml.automl:iteration 38, current learner rf
# [flaml.automl: 09-05 00:03:32] {3319} INFO -  at 13.2s,	estimator rf's best error=0.3022,	best estimator lgbm's best error=0.1752
# INFO:flaml.automl: at 13.2s,	estimator rf's best error=0.3022,	best estimator lgbm's best error=0.1752
# [flaml.automl: 09-05 00:03:32] {3133} INFO - iteration 39, current learner lgbm
# INFO:flaml.automl:iteration 39, current learner lgbm
# [flaml.automl: 09-05 00:03:32] {3319} INFO -  at 13.2s,	estimator lgbm's best error=0.1752,	best estimator lgbm's best error=0.1752
# INFO:flaml.automl: at 13.2s,	estimator lgbm's best error=0.1752,	best estimator lgbm's best error=0.1752
# [flaml.automl: 09-05 00:03:32] {3133} INFO - iteration 40, current learner rf
# INFO:flaml.automl:iteration 40, current learner rf
# [flaml.automl: 09-05 00:03:34] {3319} INFO -  at 15.2s,	estimator rf's best error=0.3006,	best estimator lgbm's best error=0.1752
# INFO:flaml.automl: at 15.2s,	estimator rf's best error=0.3006,	best estimator lgbm's best error=0.1752
# [flaml.automl: 09-05 00:03:34] {3133} INFO - iteration 41, current learner xgboost
# INFO:flaml.automl:iteration 41, current learner xgboost
# [flaml.automl: 09-05 00:03:34] {3319} INFO -  at 15.3s,	estimator xgboost's best error=0.2027,	best estimator lgbm's best error=0.1752
# INFO:flaml.automl: at 15.3s,	estimator xgboost's best error=0.2027,	best estimator lgbm's best error=0.1752
# [flaml.automl: 09-05 00:03:34] {3133} INFO - iteration 42, current learner lgbm
# INFO:flaml.automl:iteration 42, current learner lgbm
# [flaml.automl: 09-05 00:03:34] {3319} INFO -  at 15.3s,	estimator lgbm's best error=0.1752,	best estimator lgbm's best error=0.1752
# INFO:flaml.automl: at 15.3s,	estimator lgbm's best error=0.1752,	best estimator lgbm's best error=0.1752
# [flaml.automl: 09-05 00:03:34] {3133} INFO - iteration 43, current learner xgboost
# INFO:flaml.automl:iteration 43, current learner xgboost
# [flaml.automl: 09-05 00:03:34] {3319} INFO -  at 15.4s,	estimator xgboost's best error=0.2027,	best estimator lgbm's best error=0.1752
# INFO:flaml.automl: at 15.4s,	estimator xgboost's best error=0.2027,	best estimator lgbm's best error=0.1752
# [flaml.automl: 09-05 00:03:34] {3133} INFO - iteration 44, current learner extra_tree
# INFO:flaml.automl:iteration 44, current learner extra_tree
# [flaml.automl: 09-05 00:03:36] {3319} INFO -  at 16.7s,	estimator extra_tree's best error=0.2082,	best estimator lgbm's best error=0.1752
# INFO:flaml.automl: at 16.7s,	estimator extra_tree's best error=0.2082,	best estimator lgbm's best error=0.1752
# [flaml.automl: 09-05 00:03:36] {3133} INFO - iteration 45, current learner xgboost
# INFO:flaml.automl:iteration 45, current learner xgboost
# [flaml.automl: 09-05 00:03:36] {3319} INFO -  at 16.8s,	estimator xgboost's best error=0.1750,	best estimator xgboost's best error=0.1750
# INFO:flaml.automl: at 16.8s,	estimator xgboost's best error=0.1750,	best estimator xgboost's best error=0.1750
# [flaml.automl: 09-05 00:03:36] {3133} INFO - iteration 46, current learner lgbm
# INFO:flaml.automl:iteration 46, current learner lgbm
# [flaml.automl: 09-05 00:03:36] {3319} INFO -  at 16.9s,	estimator lgbm's best error=0.1752,	best estimator xgboost's best error=0.1750
# INFO:flaml.automl: at 16.9s,	estimator lgbm's best error=0.1752,	best estimator xgboost's best error=0.1750
# [flaml.automl: 09-05 00:03:36] {3133} INFO - iteration 47, current learner xgboost
# INFO:flaml.automl:iteration 47, current learner xgboost
# [flaml.automl: 09-05 00:03:36] {3319} INFO -  at 17.0s,	estimator xgboost's best error=0.1750,	best estimator xgboost's best error=0.1750
# INFO:flaml.automl: at 17.0s,	estimator xgboost's best error=0.1750,	best estimator xgboost's best error=0.1750
# [flaml.automl: 09-05 00:03:36] {3133} INFO - iteration 48, current learner lgbm
# INFO:flaml.automl:iteration 48, current learner lgbm
# [flaml.automl: 09-05 00:03:36] {3319} INFO -  at 17.0s,	estimator lgbm's best error=0.1752,	best estimator xgboost's best error=0.1750
# INFO:flaml.automl: at 17.0s,	estimator lgbm's best error=0.1752,	best estimator xgboost's best error=0.1750
# [flaml.automl: 09-05 00:03:36] {3133} INFO - iteration 49, current learner xgboost
# INFO:flaml.automl:iteration 49, current learner xgboost
# [flaml.automl: 09-05 00:03:36] {3319} INFO -  at 17.1s,	estimator xgboost's best error=0.1750,	best estimator xgboost's best error=0.1750
# INFO:flaml.automl: at 17.1s,	estimator xgboost's best error=0.1750,	best estimator xgboost's best error=0.1750
# [flaml.automl: 09-05 00:03:36] {3133} INFO - iteration 50, current learner xgboost
# INFO:flaml.automl:iteration 50, current learner xgboost
# [flaml.automl: 09-05 00:03:36] {3319} INFO -  at 17.2s,	estimator xgboost's best error=0.1750,	best estimator xgboost's best error=0.1750
# INFO:flaml.automl: at 17.2s,	estimator xgboost's best error=0.1750,	best estimator xgboost's best error=0.1750
# [flaml.automl: 09-05 00:03:36] {3133} INFO - iteration 51, current learner lgbm
# INFO:flaml.automl:iteration 51, current learner lgbm
# [flaml.automl: 09-05 00:03:36] {3319} INFO -  at 17.2s,	estimator lgbm's best error=0.1752,	best estimator xgboost's best error=0.1750
# INFO:flaml.automl: at 17.2s,	estimator lgbm's best error=0.1752,	best estimator xgboost's best error=0.1750
# [flaml.automl: 09-05 00:03:36] {3133} INFO - iteration 52, current learner lgbm
# INFO:flaml.automl:iteration 52, current learner lgbm
# [flaml.automl: 09-05 00:03:36] {3319} INFO -  at 17.3s,	estimator lgbm's best error=0.1752,	best estimator xgboost's best error=0.1750
# INFO:flaml.automl: at 17.3s,	estimator lgbm's best error=0.1752,	best estimator xgboost's best error=0.1750
# [flaml.automl: 09-05 00:03:36] {3133} INFO - iteration 53, current learner lgbm
# INFO:flaml.automl:iteration 53, current learner lgbm
# [flaml.automl: 09-05 00:03:36] {3319} INFO -  at 17.4s,	estimator lgbm's best error=0.1752,	best estimator xgboost's best error=0.1750
# INFO:flaml.automl: at 17.4s,	estimator lgbm's best error=0.1752,	best estimator xgboost's best error=0.1750
# [flaml.automl: 09-05 00:03:36] {3133} INFO - iteration 54, current learner lgbm
# INFO:flaml.automl:iteration 54, current learner lgbm
# [flaml.automl: 09-05 00:03:36] {3319} INFO -  at 17.5s,	estimator lgbm's best error=0.1752,	best estimator xgboost's best error=0.1750
# INFO:flaml.automl: at 17.5s,	estimator lgbm's best error=0.1752,	best estimator xgboost's best error=0.1750
# [flaml.automl: 09-05 00:03:36] {3133} INFO - iteration 55, current learner xgboost
# INFO:flaml.automl:iteration 55, current learner xgboost
# [flaml.automl: 09-05 00:03:36] {3319} INFO -  at 17.6s,	estimator xgboost's best error=0.1710,	best estimator xgboost's best error=0.1710
# INFO:flaml.automl: at 17.6s,	estimator xgboost's best error=0.1710,	best estimator xgboost's best error=0.1710
# [flaml.automl: 09-05 00:03:36] {3133} INFO - iteration 56, current learner xgboost
# INFO:flaml.automl:iteration 56, current learner xgboost
# [flaml.automl: 09-05 00:03:36] {3319} INFO -  at 17.6s,	estimator xgboost's best error=0.1710,	best estimator xgboost's best error=0.1710
# INFO:flaml.automl: at 17.6s,	estimator xgboost's best error=0.1710,	best estimator xgboost's best error=0.1710
# [flaml.automl: 09-05 00:03:36] {3133} INFO - iteration 57, current learner xgboost
# INFO:flaml.automl:iteration 57, current learner xgboost
# [flaml.automl: 09-05 00:03:37] {3319} INFO -  at 17.7s,	estimator xgboost's best error=0.1710,	best estimator xgboost's best error=0.1710
# INFO:flaml.automl: at 17.7s,	estimator xgboost's best error=0.1710,	best estimator xgboost's best error=0.1710
# [flaml.automl: 09-05 00:03:37] {3133} INFO - iteration 58, current learner xgboost
# INFO:flaml.automl:iteration 58, current learner xgboost
# [flaml.automl: 09-05 00:03:37] {3319} INFO -  at 17.8s,	estimator xgboost's best error=0.1694,	best estimator xgboost's best error=0.1694
# INFO:flaml.automl: at 17.8s,	estimator xgboost's best error=0.1694,	best estimator xgboost's best error=0.1694
# [flaml.automl: 09-05 00:03:37] {3133} INFO - iteration 59, current learner xgboost
# INFO:flaml.automl:iteration 59, current learner xgboost
# [flaml.automl: 09-05 00:03:37] {3319} INFO -  at 17.9s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 17.9s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:37] {3133} INFO - iteration 60, current learner xgboost
# INFO:flaml.automl:iteration 60, current learner xgboost
# [flaml.automl: 09-05 00:03:37] {3319} INFO -  at 18.0s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 18.0s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:37] {3133} INFO - iteration 61, current learner xgboost
# INFO:flaml.automl:iteration 61, current learner xgboost
# [flaml.automl: 09-05 00:03:37] {3319} INFO -  at 18.1s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 18.1s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:37] {3133} INFO - iteration 62, current learner xgboost
# INFO:flaml.automl:iteration 62, current learner xgboost
# [flaml.automl: 09-05 00:03:37] {3319} INFO -  at 18.1s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 18.1s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:37] {3133} INFO - iteration 63, current learner xgboost
# INFO:flaml.automl:iteration 63, current learner xgboost
# [flaml.automl: 09-05 00:03:37] {3319} INFO -  at 18.2s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 18.2s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:37] {3133} INFO - iteration 64, current learner xgboost
# INFO:flaml.automl:iteration 64, current learner xgboost
# [flaml.automl: 09-05 00:03:37] {3319} INFO -  at 18.3s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 18.3s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:37] {3133} INFO - iteration 65, current learner xgboost
# INFO:flaml.automl:iteration 65, current learner xgboost
# [flaml.automl: 09-05 00:03:37] {3319} INFO -  at 18.4s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 18.4s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:37] {3133} INFO - iteration 66, current learner xgboost
# INFO:flaml.automl:iteration 66, current learner xgboost
# [flaml.automl: 09-05 00:03:37] {3319} INFO -  at 18.4s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 18.4s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:37] {3133} INFO - iteration 67, current learner xgboost
# INFO:flaml.automl:iteration 67, current learner xgboost
# [flaml.automl: 09-05 00:03:37] {3319} INFO -  at 18.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 18.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:37] {3133} INFO - iteration 68, current learner xgboost
# INFO:flaml.automl:iteration 68, current learner xgboost
# [flaml.automl: 09-05 00:03:37] {3319} INFO -  at 18.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 18.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:37] {3133} INFO - iteration 69, current learner xgboost
# INFO:flaml.automl:iteration 69, current learner xgboost
# [flaml.automl: 09-05 00:03:38] {3319} INFO -  at 18.7s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 18.7s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:38] {3133} INFO - iteration 70, current learner xgboost
# INFO:flaml.automl:iteration 70, current learner xgboost
# [flaml.automl: 09-05 00:03:38] {3319} INFO -  at 18.7s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 18.7s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:38] {3133} INFO - iteration 71, current learner xgboost
# INFO:flaml.automl:iteration 71, current learner xgboost
# [flaml.automl: 09-05 00:03:38] {3319} INFO -  at 18.8s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 18.8s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:38] {3133} INFO - iteration 72, current learner extra_tree
# INFO:flaml.automl:iteration 72, current learner extra_tree
# [flaml.automl: 09-05 00:03:39] {3319} INFO -  at 20.0s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 20.0s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:39] {3133} INFO - iteration 73, current learner xgboost
# INFO:flaml.automl:iteration 73, current learner xgboost
# [flaml.automl: 09-05 00:03:39] {3319} INFO -  at 20.1s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 20.1s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:39] {3133} INFO - iteration 74, current learner xgboost
# INFO:flaml.automl:iteration 74, current learner xgboost
# [flaml.automl: 09-05 00:03:39] {3319} INFO -  at 20.2s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 20.2s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:39] {3133} INFO - iteration 75, current learner xgboost
# INFO:flaml.automl:iteration 75, current learner xgboost
# [flaml.automl: 09-05 00:03:39] {3319} INFO -  at 20.3s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 20.3s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:39] {3133} INFO - iteration 76, current learner xgboost
# INFO:flaml.automl:iteration 76, current learner xgboost
# [flaml.automl: 09-05 00:03:39] {3319} INFO -  at 20.4s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 20.4s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:39] {3133} INFO - iteration 77, current learner xgboost
# INFO:flaml.automl:iteration 77, current learner xgboost
# [flaml.automl: 09-05 00:03:39] {3319} INFO -  at 20.4s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 20.4s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:39] {3133} INFO - iteration 78, current learner xgboost
# INFO:flaml.automl:iteration 78, current learner xgboost
# [flaml.automl: 09-05 00:03:39] {3319} INFO -  at 20.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 20.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:39] {3133} INFO - iteration 79, current learner xgboost
# INFO:flaml.automl:iteration 79, current learner xgboost
# [flaml.automl: 09-05 00:03:39] {3319} INFO -  at 20.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 20.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:39] {3133} INFO - iteration 80, current learner extra_tree
# INFO:flaml.automl:iteration 80, current learner extra_tree
# [flaml.automl: 09-05 00:03:41] {3319} INFO -  at 21.9s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 21.9s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:41] {3133} INFO - iteration 81, current learner xgboost
# INFO:flaml.automl:iteration 81, current learner xgboost
# [flaml.automl: 09-05 00:03:41] {3319} INFO -  at 22.0s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 22.0s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:41] {3133} INFO - iteration 82, current learner xgboost
# INFO:flaml.automl:iteration 82, current learner xgboost
# [flaml.automl: 09-05 00:03:41] {3319} INFO -  at 22.1s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 22.1s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:41] {3133} INFO - iteration 83, current learner xgboost
# INFO:flaml.automl:iteration 83, current learner xgboost
# [flaml.automl: 09-05 00:03:41] {3319} INFO -  at 22.2s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 22.2s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:41] {3133} INFO - iteration 84, current learner extra_tree
# INFO:flaml.automl:iteration 84, current learner extra_tree
# [flaml.automl: 09-05 00:03:42] {3319} INFO -  at 23.3s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 23.3s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:42] {3133} INFO - iteration 85, current learner xgboost
# INFO:flaml.automl:iteration 85, current learner xgboost
# [flaml.automl: 09-05 00:03:42] {3319} INFO -  at 23.4s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 23.4s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:42] {3133} INFO - iteration 86, current learner xgboost
# INFO:flaml.automl:iteration 86, current learner xgboost
# [flaml.automl: 09-05 00:03:42] {3319} INFO -  at 23.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 23.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:42] {3133} INFO - iteration 87, current learner xgboost
# INFO:flaml.automl:iteration 87, current learner xgboost
# [flaml.automl: 09-05 00:03:42] {3319} INFO -  at 23.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 23.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:42] {3133} INFO - iteration 88, current learner xgboost
# INFO:flaml.automl:iteration 88, current learner xgboost
# [flaml.automl: 09-05 00:03:43] {3319} INFO -  at 23.7s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 23.7s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:43] {3133} INFO - iteration 89, current learner extra_tree
# INFO:flaml.automl:iteration 89, current learner extra_tree
# [flaml.automl: 09-05 00:03:44] {3319} INFO -  at 24.9s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 24.9s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:44] {3133} INFO - iteration 90, current learner xgboost
# INFO:flaml.automl:iteration 90, current learner xgboost
# [flaml.automl: 09-05 00:03:44] {3319} INFO -  at 25.0s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 25.0s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:44] {3133} INFO - iteration 91, current learner extra_tree
# INFO:flaml.automl:iteration 91, current learner extra_tree
# [flaml.automl: 09-05 00:03:45] {3319} INFO -  at 26.2s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 26.2s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:45] {3133} INFO - iteration 92, current learner xgboost
# INFO:flaml.automl:iteration 92, current learner xgboost
# [flaml.automl: 09-05 00:03:45] {3319} INFO -  at 26.3s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 26.3s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:45] {3133} INFO - iteration 93, current learner xgboost
# INFO:flaml.automl:iteration 93, current learner xgboost
# [flaml.automl: 09-05 00:03:45] {3319} INFO -  at 26.4s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 26.4s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:45] {3133} INFO - iteration 94, current learner xgboost
# INFO:flaml.automl:iteration 94, current learner xgboost
# [flaml.automl: 09-05 00:03:45] {3319} INFO -  at 26.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 26.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:45] {3133} INFO - iteration 95, current learner extra_tree
# INFO:flaml.automl:iteration 95, current learner extra_tree
# [flaml.automl: 09-05 00:03:46] {3319} INFO -  at 27.7s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 27.7s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:47] {3133} INFO - iteration 96, current learner xgboost
# INFO:flaml.automl:iteration 96, current learner xgboost
# [flaml.automl: 09-05 00:03:47] {3319} INFO -  at 27.7s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 27.7s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:47] {3133} INFO - iteration 97, current learner xgboost
# INFO:flaml.automl:iteration 97, current learner xgboost
# [flaml.automl: 09-05 00:03:47] {3319} INFO -  at 27.8s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 27.8s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:47] {3133} INFO - iteration 98, current learner xgboost
# INFO:flaml.automl:iteration 98, current learner xgboost
# [flaml.automl: 09-05 00:03:47] {3319} INFO -  at 27.9s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 27.9s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:47] {3133} INFO - iteration 99, current learner xgboost
# INFO:flaml.automl:iteration 99, current learner xgboost
# [flaml.automl: 09-05 00:03:47] {3319} INFO -  at 28.0s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 28.0s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:47] {3133} INFO - iteration 100, current learner extra_tree
# INFO:flaml.automl:iteration 100, current learner extra_tree
# [flaml.automl: 09-05 00:03:48] {3319} INFO -  at 29.3s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 29.3s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:48] {3133} INFO - iteration 101, current learner xgboost
# INFO:flaml.automl:iteration 101, current learner xgboost
# [flaml.automl: 09-05 00:03:48] {3319} INFO -  at 29.3s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 29.3s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:48] {3133} INFO - iteration 102, current learner lgbm
# INFO:flaml.automl:iteration 102, current learner lgbm
# [flaml.automl: 09-05 00:03:48] {3319} INFO -  at 29.4s,	estimator lgbm's best error=0.1752,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 29.4s,	estimator lgbm's best error=0.1752,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:48] {3133} INFO - iteration 103, current learner xgboost
# INFO:flaml.automl:iteration 103, current learner xgboost
# [flaml.automl: 09-05 00:03:48] {3319} INFO -  at 29.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 29.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:48] {3133} INFO - iteration 104, current learner xgboost
# INFO:flaml.automl:iteration 104, current learner xgboost
# [flaml.automl: 09-05 00:03:48] {3319} INFO -  at 29.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 29.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:48] {3133} INFO - iteration 105, current learner xgboost
# INFO:flaml.automl:iteration 105, current learner xgboost
# [flaml.automl: 09-05 00:03:48] {3319} INFO -  at 29.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 29.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:48] {3133} INFO - iteration 106, current learner extra_tree
# INFO:flaml.automl:iteration 106, current learner extra_tree
# [flaml.automl: 09-05 00:03:50] {3319} INFO -  at 30.8s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 30.8s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:50] {3133} INFO - iteration 107, current learner xgboost
# INFO:flaml.automl:iteration 107, current learner xgboost
# [flaml.automl: 09-05 00:03:50] {3319} INFO -  at 30.9s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 30.9s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:50] {3133} INFO - iteration 108, current learner extra_tree
# INFO:flaml.automl:iteration 108, current learner extra_tree
# [flaml.automl: 09-05 00:03:51] {3319} INFO -  at 32.5s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 32.5s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:51] {3133} INFO - iteration 109, current learner xgboost
# INFO:flaml.automl:iteration 109, current learner xgboost
# [flaml.automl: 09-05 00:03:51] {3319} INFO -  at 32.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 32.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:51] {3133} INFO - iteration 110, current learner lgbm
# INFO:flaml.automl:iteration 110, current learner lgbm
# [flaml.automl: 09-05 00:03:51] {3319} INFO -  at 32.6s,	estimator lgbm's best error=0.1752,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 32.6s,	estimator lgbm's best error=0.1752,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:51] {3133} INFO - iteration 111, current learner extra_tree
# INFO:flaml.automl:iteration 111, current learner extra_tree
# [flaml.automl: 09-05 00:03:53] {3319} INFO -  at 33.9s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 33.9s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:53] {3133} INFO - iteration 112, current learner xgboost
# INFO:flaml.automl:iteration 112, current learner xgboost
# [flaml.automl: 09-05 00:03:53] {3319} INFO -  at 34.0s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 34.0s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:53] {3133} INFO - iteration 113, current learner extra_tree
# INFO:flaml.automl:iteration 113, current learner extra_tree
# [flaml.automl: 09-05 00:03:54] {3319} INFO -  at 35.5s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 35.5s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:54] {3133} INFO - iteration 114, current learner xgboost
# INFO:flaml.automl:iteration 114, current learner xgboost
# [flaml.automl: 09-05 00:03:54] {3319} INFO -  at 35.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 35.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:54] {3133} INFO - iteration 115, current learner xgboost
# INFO:flaml.automl:iteration 115, current learner xgboost
# [flaml.automl: 09-05 00:03:54] {3319} INFO -  at 35.7s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 35.7s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:55] {3133} INFO - iteration 116, current learner extra_tree
# INFO:flaml.automl:iteration 116, current learner extra_tree
# [flaml.automl: 09-05 00:03:56] {3319} INFO -  at 36.8s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 36.8s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:56] {3133} INFO - iteration 117, current learner xgboost
# INFO:flaml.automl:iteration 117, current learner xgboost
# [flaml.automl: 09-05 00:03:56] {3319} INFO -  at 36.9s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 36.9s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:56] {3133} INFO - iteration 118, current learner lgbm
# INFO:flaml.automl:iteration 118, current learner lgbm
# [flaml.automl: 09-05 00:03:56] {3319} INFO -  at 37.0s,	estimator lgbm's best error=0.1752,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 37.0s,	estimator lgbm's best error=0.1752,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:56] {3133} INFO - iteration 119, current learner xgboost
# INFO:flaml.automl:iteration 119, current learner xgboost
# [flaml.automl: 09-05 00:03:56] {3319} INFO -  at 37.1s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 37.1s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:56] {3133} INFO - iteration 120, current learner xgboost
# INFO:flaml.automl:iteration 120, current learner xgboost
# [flaml.automl: 09-05 00:03:56] {3319} INFO -  at 37.1s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 37.1s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:56] {3133} INFO - iteration 121, current learner extra_tree
# INFO:flaml.automl:iteration 121, current learner extra_tree
# [flaml.automl: 09-05 00:03:57] {3319} INFO -  at 38.4s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 38.4s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:57] {3133} INFO - iteration 122, current learner xgboost
# INFO:flaml.automl:iteration 122, current learner xgboost
# [flaml.automl: 09-05 00:03:57] {3319} INFO -  at 38.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 38.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:57] {3133} INFO - iteration 123, current learner xgboost
# INFO:flaml.automl:iteration 123, current learner xgboost
# [flaml.automl: 09-05 00:03:57] {3319} INFO -  at 38.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 38.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:57] {3133} INFO - iteration 124, current learner lgbm
# INFO:flaml.automl:iteration 124, current learner lgbm
# [flaml.automl: 09-05 00:03:58] {3319} INFO -  at 38.7s,	estimator lgbm's best error=0.1748,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 38.7s,	estimator lgbm's best error=0.1748,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:58] {3133} INFO - iteration 125, current learner rf
# INFO:flaml.automl:iteration 125, current learner rf
# [flaml.automl: 09-05 00:03:59] {3319} INFO -  at 40.2s,	estimator rf's best error=0.2552,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 40.2s,	estimator rf's best error=0.2552,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:03:59] {3133} INFO - iteration 126, current learner rf
# INFO:flaml.automl:iteration 126, current learner rf
# [flaml.automl: 09-05 00:04:00] {3319} INFO -  at 41.5s,	estimator rf's best error=0.2552,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 41.5s,	estimator rf's best error=0.2552,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:00] {3133} INFO - iteration 127, current learner xgboost
# INFO:flaml.automl:iteration 127, current learner xgboost
# [flaml.automl: 09-05 00:04:00] {3319} INFO -  at 41.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 41.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:00] {3133} INFO - iteration 128, current learner xgboost
# INFO:flaml.automl:iteration 128, current learner xgboost
# [flaml.automl: 09-05 00:04:00] {3319} INFO -  at 41.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 41.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:00] {3133} INFO - iteration 129, current learner xgboost
# INFO:flaml.automl:iteration 129, current learner xgboost
# [flaml.automl: 09-05 00:04:01] {3319} INFO -  at 41.7s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 41.7s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:01] {3133} INFO - iteration 130, current learner xgboost
# INFO:flaml.automl:iteration 130, current learner xgboost
# [flaml.automl: 09-05 00:04:01] {3319} INFO -  at 41.8s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 41.8s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:01] {3133} INFO - iteration 131, current learner xgboost
# INFO:flaml.automl:iteration 131, current learner xgboost
# [flaml.automl: 09-05 00:04:01] {3319} INFO -  at 41.9s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 41.9s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:01] {3133} INFO - iteration 132, current learner rf
# INFO:flaml.automl:iteration 132, current learner rf
# [flaml.automl: 09-05 00:04:02] {3319} INFO -  at 43.6s,	estimator rf's best error=0.2552,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 43.6s,	estimator rf's best error=0.2552,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:02] {3133} INFO - iteration 133, current learner xgboost
# INFO:flaml.automl:iteration 133, current learner xgboost
# [flaml.automl: 09-05 00:04:03] {3319} INFO -  at 43.7s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 43.7s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:03] {3133} INFO - iteration 134, current learner xgboost
# INFO:flaml.automl:iteration 134, current learner xgboost
# [flaml.automl: 09-05 00:04:03] {3319} INFO -  at 43.8s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 43.8s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:03] {3133} INFO - iteration 135, current learner extra_tree
# INFO:flaml.automl:iteration 135, current learner extra_tree
# [flaml.automl: 09-05 00:04:04] {3319} INFO -  at 45.0s,	estimator extra_tree's best error=0.1899,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 45.0s,	estimator extra_tree's best error=0.1899,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:04] {3133} INFO - iteration 136, current learner xgboost
# INFO:flaml.automl:iteration 136, current learner xgboost
# [flaml.automl: 09-05 00:04:04] {3319} INFO -  at 45.1s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 45.1s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:04] {3133} INFO - iteration 137, current learner lgbm
# INFO:flaml.automl:iteration 137, current learner lgbm
# [flaml.automl: 09-05 00:04:04] {3319} INFO -  at 45.1s,	estimator lgbm's best error=0.1748,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 45.1s,	estimator lgbm's best error=0.1748,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:04] {3133} INFO - iteration 138, current learner xgboost
# INFO:flaml.automl:iteration 138, current learner xgboost
# [flaml.automl: 09-05 00:04:04] {3319} INFO -  at 45.2s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 45.2s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:04] {3133} INFO - iteration 139, current learner xgboost
# INFO:flaml.automl:iteration 139, current learner xgboost
# [flaml.automl: 09-05 00:04:04] {3319} INFO -  at 45.3s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 45.3s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:04] {3133} INFO - iteration 140, current learner xgboost
# INFO:flaml.automl:iteration 140, current learner xgboost
# [flaml.automl: 09-05 00:04:04] {3319} INFO -  at 45.4s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 45.4s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:04] {3133} INFO - iteration 141, current learner xgboost
# INFO:flaml.automl:iteration 141, current learner xgboost
# [flaml.automl: 09-05 00:04:04] {3319} INFO -  at 45.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 45.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:04] {3133} INFO - iteration 142, current learner xgboost
# INFO:flaml.automl:iteration 142, current learner xgboost
# [flaml.automl: 09-05 00:04:04] {3319} INFO -  at 45.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 45.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:04] {3133} INFO - iteration 143, current learner xgboost
# INFO:flaml.automl:iteration 143, current learner xgboost
# [flaml.automl: 09-05 00:04:04] {3319} INFO -  at 45.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 45.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:04] {3133} INFO - iteration 144, current learner xgboost
# INFO:flaml.automl:iteration 144, current learner xgboost
# [flaml.automl: 09-05 00:04:05] {3319} INFO -  at 45.7s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 45.7s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:05] {3133} INFO - iteration 145, current learner rf
# INFO:flaml.automl:iteration 145, current learner rf
# [flaml.automl: 09-05 00:04:06] {3319} INFO -  at 47.0s,	estimator rf's best error=0.2552,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 47.0s,	estimator rf's best error=0.2552,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:06] {3133} INFO - iteration 146, current learner rf
# INFO:flaml.automl:iteration 146, current learner rf
# [flaml.automl: 09-05 00:04:07] {3319} INFO -  at 48.3s,	estimator rf's best error=0.2552,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 48.3s,	estimator rf's best error=0.2552,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:07] {3133} INFO - iteration 147, current learner rf
# INFO:flaml.automl:iteration 147, current learner rf
# [flaml.automl: 09-05 00:04:09] {3319} INFO -  at 49.8s,	estimator rf's best error=0.2552,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 49.8s,	estimator rf's best error=0.2552,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:09] {3133} INFO - iteration 148, current learner rf
# INFO:flaml.automl:iteration 148, current learner rf
# [flaml.automl: 09-05 00:04:10] {3319} INFO -  at 51.2s,	estimator rf's best error=0.2552,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 51.2s,	estimator rf's best error=0.2552,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:10] {3133} INFO - iteration 149, current learner xgboost
# INFO:flaml.automl:iteration 149, current learner xgboost
# [flaml.automl: 09-05 00:04:10] {3319} INFO -  at 51.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 51.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:10] {3133} INFO - iteration 150, current learner xgboost
# INFO:flaml.automl:iteration 150, current learner xgboost
# [flaml.automl: 09-05 00:04:11] {3319} INFO -  at 51.7s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 51.7s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:11] {3133} INFO - iteration 151, current learner xgboost
# INFO:flaml.automl:iteration 151, current learner xgboost
# [flaml.automl: 09-05 00:04:11] {3319} INFO -  at 52.2s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 52.2s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:11] {3133} INFO - iteration 152, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 152, current learner xgb_limitdepth
# [flaml.automl: 09-05 00:04:11] {3319} INFO -  at 52.5s,	estimator xgb_limitdepth's best error=0.2674,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 52.5s,	estimator xgb_limitdepth's best error=0.2674,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:11] {3133} INFO - iteration 153, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 153, current learner xgb_limitdepth
# [flaml.automl: 09-05 00:04:12] {3319} INFO -  at 52.7s,	estimator xgb_limitdepth's best error=0.1759,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 52.7s,	estimator xgb_limitdepth's best error=0.1759,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:12] {3133} INFO - iteration 154, current learner xgboost
# INFO:flaml.automl:iteration 154, current learner xgboost
# [flaml.automl: 09-05 00:04:12] {3319} INFO -  at 52.8s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 52.8s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:12] {3133} INFO - iteration 155, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 155, current learner xgb_limitdepth
# [flaml.automl: 09-05 00:04:12] {3319} INFO -  at 53.1s,	estimator xgb_limitdepth's best error=0.1759,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 53.1s,	estimator xgb_limitdepth's best error=0.1759,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:12] {3133} INFO - iteration 156, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 156, current learner xgb_limitdepth
# [flaml.automl: 09-05 00:04:12] {3319} INFO -  at 53.3s,	estimator xgb_limitdepth's best error=0.1759,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 53.3s,	estimator xgb_limitdepth's best error=0.1759,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:12] {3133} INFO - iteration 157, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 157, current learner xgb_limitdepth
# [flaml.automl: 09-05 00:04:12] {3319} INFO -  at 53.6s,	estimator xgb_limitdepth's best error=0.1759,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 53.6s,	estimator xgb_limitdepth's best error=0.1759,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:04:12] {3133} INFO - iteration 158, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 158, current learner xgb_limitdepth
# [flaml.automl: 09-05 00:04:13] {3319} INFO -  at 53.8s,	estimator xgb_limitdepth's best error=0.1759,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 53.8s,	estimator xgb_limitdepth's best error=0.1759,	best estimator xgboost's best error=0.1468
# ...
# [flaml.automl: 09-05 00:08:11] {3319} INFO -  at 292.4s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 292.4s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:11] {3133} INFO - iteration 997, current learner lgbm
# INFO:flaml.automl:iteration 997, current learner lgbm
# [flaml.automl: 09-05 00:08:11] {3319} INFO -  at 292.5s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 292.5s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:11] {3133} INFO - iteration 998, current learner xgboost
# INFO:flaml.automl:iteration 998, current learner xgboost
# [flaml.automl: 09-05 00:08:11] {3319} INFO -  at 292.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 292.6s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:11] {3133} INFO - iteration 999, current learner lgbm
# INFO:flaml.automl:iteration 999, current learner lgbm
# [flaml.automl: 09-05 00:08:12] {3319} INFO -  at 292.8s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 292.8s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:12] {3133} INFO - iteration 1000, current learner xgboost
# INFO:flaml.automl:iteration 1000, current learner xgboost
# [flaml.automl: 09-05 00:08:12] {3319} INFO -  at 292.9s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 292.9s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:12] {3133} INFO - iteration 1001, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 1001, current learner xgb_limitdepth
# [flaml.automl: 09-05 00:08:12] {3319} INFO -  at 293.0s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 293.0s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:12] {3133} INFO - iteration 1002, current learner lgbm
# INFO:flaml.automl:iteration 1002, current learner lgbm
# [flaml.automl: 09-05 00:08:12] {3319} INFO -  at 293.2s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 293.2s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:12] {3133} INFO - iteration 1003, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 1003, current learner xgb_limitdepth
# [flaml.automl: 09-05 00:08:12] {3319} INFO -  at 293.3s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 293.3s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:12] {3133} INFO - iteration 1004, current learner lgbm
# INFO:flaml.automl:iteration 1004, current learner lgbm
# [flaml.automl: 09-05 00:08:12] {3319} INFO -  at 293.4s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 293.4s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:12] {3133} INFO - iteration 1005, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 1005, current learner xgb_limitdepth
# [flaml.automl: 09-05 00:08:12] {3319} INFO -  at 293.5s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 293.5s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:12] {3133} INFO - iteration 1006, current learner lgbm
# INFO:flaml.automl:iteration 1006, current learner lgbm
# [flaml.automl: 09-05 00:08:13] {3319} INFO -  at 293.7s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 293.7s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:13] {3133} INFO - iteration 1007, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 1007, current learner xgb_limitdepth
# [flaml.automl: 09-05 00:08:13] {3319} INFO -  at 293.8s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 293.8s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:13] {3133} INFO - iteration 1008, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 1008, current learner xgb_limitdepth
# [flaml.automl: 09-05 00:08:13] {3319} INFO -  at 294.0s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 294.0s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:13] {3133} INFO - iteration 1009, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 1009, current learner xgb_limitdepth
# [flaml.automl: 09-05 00:08:13] {3319} INFO -  at 294.2s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 294.2s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:13] {3133} INFO - iteration 1010, current learner xgboost
# INFO:flaml.automl:iteration 1010, current learner xgboost
# [flaml.automl: 09-05 00:08:13] {3319} INFO -  at 294.3s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 294.3s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:13] {3133} INFO - iteration 1011, current learner lgbm
# INFO:flaml.automl:iteration 1011, current learner lgbm
# [flaml.automl: 09-05 00:08:13] {3319} INFO -  at 294.4s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 294.4s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:13] {3133} INFO - iteration 1012, current learner lgbm
# INFO:flaml.automl:iteration 1012, current learner lgbm
# [flaml.automl: 09-05 00:08:13] {3319} INFO -  at 294.5s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 294.5s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:13] {3133} INFO - iteration 1013, current learner lgbm
# INFO:flaml.automl:iteration 1013, current learner lgbm
# [flaml.automl: 09-05 00:08:14] {3319} INFO -  at 294.7s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 294.7s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:14] {3133} INFO - iteration 1014, current learner lgbm
# INFO:flaml.automl:iteration 1014, current learner lgbm
# [flaml.automl: 09-05 00:08:14] {3319} INFO -  at 294.8s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 294.8s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:14] {3133} INFO - iteration 1015, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 1015, current learner xgb_limitdepth
# [flaml.automl: 09-05 00:08:14] {3319} INFO -  at 295.0s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 295.0s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:14] {3133} INFO - iteration 1016, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 1016, current learner xgb_limitdepth
# [flaml.automl: 09-05 00:08:14] {3319} INFO -  at 295.1s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 295.1s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:14] {3133} INFO - iteration 1017, current learner xgboost
# INFO:flaml.automl:iteration 1017, current learner xgboost
# [flaml.automl: 09-05 00:08:14] {3319} INFO -  at 295.2s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 295.2s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:14] {3133} INFO - iteration 1018, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 1018, current learner xgb_limitdepth
# [flaml.automl: 09-05 00:08:14] {3319} INFO -  at 295.4s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 295.4s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:14] {3133} INFO - iteration 1019, current learner xgboost
# INFO:flaml.automl:iteration 1019, current learner xgboost
# [flaml.automl: 09-05 00:08:14] {3319} INFO -  at 295.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 295.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:14] {3133} INFO - iteration 1020, current learner lgbm
# INFO:flaml.automl:iteration 1020, current learner lgbm
# [flaml.automl: 09-05 00:08:14] {3319} INFO -  at 295.6s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 295.6s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:14] {3133} INFO - iteration 1021, current learner lgbm
# INFO:flaml.automl:iteration 1021, current learner lgbm
# [flaml.automl: 09-05 00:08:15] {3319} INFO -  at 295.8s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 295.8s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:15] {3133} INFO - iteration 1022, current learner lgbm
# INFO:flaml.automl:iteration 1022, current learner lgbm
# [flaml.automl: 09-05 00:08:15] {3319} INFO -  at 295.9s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 295.9s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:15] {3133} INFO - iteration 1023, current learner lgbm
# INFO:flaml.automl:iteration 1023, current learner lgbm
# [flaml.automl: 09-05 00:08:15] {3319} INFO -  at 296.0s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 296.0s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:15] {3133} INFO - iteration 1024, current learner lgbm
# INFO:flaml.automl:iteration 1024, current learner lgbm
# [flaml.automl: 09-05 00:08:15] {3319} INFO -  at 296.2s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 296.2s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:15] {3133} INFO - iteration 1025, current learner extra_tree
# INFO:flaml.automl:iteration 1025, current learner extra_tree
# [flaml.automl: 09-05 00:08:17] {3319} INFO -  at 297.7s,	estimator extra_tree's best error=0.1811,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 297.7s,	estimator extra_tree's best error=0.1811,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:17] {3133} INFO - iteration 1026, current learner xgboost
# INFO:flaml.automl:iteration 1026, current learner xgboost
# [flaml.automl: 09-05 00:08:17] {3319} INFO -  at 297.8s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 297.8s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:17] {3133} INFO - iteration 1027, current learner extra_tree
# INFO:flaml.automl:iteration 1027, current learner extra_tree
# [flaml.automl: 09-05 00:08:18] {3319} INFO -  at 299.4s,	estimator extra_tree's best error=0.1811,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 299.4s,	estimator extra_tree's best error=0.1811,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:18] {3133} INFO - iteration 1028, current learner xgboost
# INFO:flaml.automl:iteration 1028, current learner xgboost
# [flaml.automl: 09-05 00:08:18] {3319} INFO -  at 299.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 299.5s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:18] {3133} INFO - iteration 1029, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 1029, current learner xgb_limitdepth
# [flaml.automl: 09-05 00:08:18] {3319} INFO -  at 299.6s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 299.6s,	estimator xgb_limitdepth's best error=0.1470,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:18] {3133} INFO - iteration 1030, current learner xgboost
# INFO:flaml.automl:iteration 1030, current learner xgboost
# [flaml.automl: 09-05 00:08:19] {3319} INFO -  at 299.8s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 299.8s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:19] {3133} INFO - iteration 1031, current learner lgbm
# INFO:flaml.automl:iteration 1031, current learner lgbm
# [flaml.automl: 09-05 00:08:19] {3319} INFO -  at 299.9s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 299.9s,	estimator lgbm's best error=0.1484,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:19] {3133} INFO - iteration 1032, current learner xgboost
# INFO:flaml.automl:iteration 1032, current learner xgboost
# [flaml.automl: 09-05 00:08:19] {3319} INFO -  at 300.0s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# INFO:flaml.automl: at 300.0s,	estimator xgboost's best error=0.1468,	best estimator xgboost's best error=0.1468
# [flaml.automl: 09-05 00:08:19] {3579} INFO - retrain xgboost for 0.0s
# INFO:flaml.automl:retrain xgboost for 0.0s
# [flaml.automl: 09-05 00:08:19] {3584} INFO - retrained model: XGBClassifier(colsample_bylevel=0.7905358317292889,
#               colsample_bytree=0.9544060556215052, grow_policy='lossguide',
#               learning_rate=0.11677765280016518, max_depth=0, max_leaves=6,
#               min_child_weight=5.8614537300277965, n_estimators=7, n_jobs=-1,
#               reg_alpha=0.0015245843735931766, reg_lambda=0.5536296597037936,
#               subsample=0.8895588746662894, tree_method='hist',
#               use_label_encoder=False, verbosity=0)
# INFO:flaml.automl:retrained model: XGBClassifier(colsample_bylevel=0.7905358317292889,
#               colsample_bytree=0.9544060556215052, grow_policy='lossguide',
#               learning_rate=0.11677765280016518, max_depth=0, max_leaves=6,
#               min_child_weight=5.8614537300277965, n_estimators=7, n_jobs=-1,
#               reg_alpha=0.0015245843735931766, reg_lambda=0.5536296597037936,
#               subsample=0.8895588746662894, tree_method='hist',
#               use_label_encoder=False, verbosity=0)
# [flaml.automl: 09-05 00:08:19] {2862} INFO - fit succeeded
# INFO:flaml.automl:fit succeeded
# [flaml.automl: 09-05 00:08:19] {2864} INFO - Time taken to find the best model: 17.883115768432617
# INFO:flaml.automl:Time taken to find the best model: 17.883115768432617

# %%
print(automl.model)
# Out:
# <flaml.model.XGBoostSklearnEstimator object at 0x7fcdef8c1ed0>

# %%
automl.best_estimator
# Out:
# 'xgboost'

# %%
params = automl.best_config_per_estimator['xgboost']
params
# Out:
# {'n_estimators': 7,
#  'max_leaves': 6,
#  'min_child_weight': 5.8614537300277965,
#  'learning_rate': 0.11677765280016518,
#  'subsample': 0.8895588746662894,
#  'colsample_bylevel': 0.7905358317292889,
#  'colsample_bytree': 0.9544060556215052,
#  'reg_alpha': 0.0015245843735931766,
#  'reg_lambda': 0.5536296597037936}

# %% [markdown]
# ## Test the XGBoost with Params

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score

# %%
clf = XGBClassifier()
clf.set_params(**params)
scores = cross_val_score(clf, X, y, scoring='precision')

# %%
np.mean(scores)
# Out:
# 0.5533333333333333

# %%
clf.get_params()
# Out:
# {'base_score': 0.5,
#  'booster': 'gbtree',
#  'colsample_bylevel': 0.7905358317292889,
#  'colsample_bynode': 1,
#  'colsample_bytree': 0.9544060556215052,
#  'gamma': 0,
#  'learning_rate': 0.11677765280016518,
#  'max_delta_step': 0,
#  'max_depth': 3,
#  'min_child_weight': 5.8614537300277965,
#  'missing': None,
#  'n_estimators': 7,
#  'n_jobs': 1,
#  'nthread': None,
#  'objective': 'binary:logistic',
#  'random_state': 0,
#  'reg_alpha': 0.0015245843735931766,
#  'reg_lambda': 0.5536296597037936,
#  'scale_pos_weight': 1,
#  'seed': None,
#  'silent': None,
#  'subsample': 0.8895588746662894,
#  'verbosity': 1,
#  'max_leaves': 6}

# %%
clf.fit(X,y)
y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95        81
#            1       0.80      0.33      0.47        12
#
#     accuracy                           0.90        93
#    macro avg       0.85      0.66      0.71        93
# weighted avg       0.90      0.90      0.89        93
