# %% [markdown]
# # myopia_flaml.ipynb
#
# - This notebook was run in Google Colaboratory
# - The technology used in FLAML is Microsofts's AutoML

# %%
# !python --version
# Out:
# Python 3.7.13

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ----------------------------
# absl-py                       1.2.0
# aeppl                         0.0.33
# aesara                        2.7.9
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# albumentations                1.2.1
# altair                        4.2.0
# appdirs                       1.4.4
# arviz                         0.12.1
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# async-timeout                 4.0.2
# asynctest                     0.13.0
# atari-py                      0.2.9
# atomicwrites                  1.4.1
# attrs                         22.1.0
# audioread                     3.0.0
# autograd                      1.4
# Babel                         2.10.3
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        5.0.1
# blis                          0.7.8
# bokeh                         2.3.3
# branca                        0.5.0
# bs4                           0.0.1
# CacheControl                  0.12.11
# cached-property               1.5.2
# cachetools                    4.2.4
# catalogue                     2.0.8
# certifi                       2022.6.15
# cffi                          1.15.1
# cftime                        1.6.1
# chardet                       3.0.4
# charset-normalizer            2.1.1
# click                         7.1.2
# clikit                        0.6.2
# cloudpickle                   1.5.0
# cmake                         3.22.6
# cmdstanpy                     1.0.7
# colorcet                      3.0.0
# colorlover                    0.3.0
# community                     1.0.0b1
# cons                          0.4.5
# contextlib2                   0.5.5
# convertdate                   2.4.0
# crashtest                     0.3.1
# crcmod                        1.7
# cufflinks                     0.17.3
# cvxopt                        1.3.0
# cvxpy                         1.2.1
# cycler                        0.11.0
# cymem                         2.0.6
# Cython                        0.29.32
# daft                          0.0.4
# dask                          2022.2.0
# datascience                   0.17.5
# debugpy                       1.0.0
# decorator                     4.4.2
# defusedxml                    0.7.1
# descartes                     1.1.0
# dill                          0.3.5.1
# distributed                   2022.2.0
# dlib                          19.24.0
# dm-tree                       0.1.7
# docutils                      0.17.1
# dopamine-rl                   1.0.5
# earthengine-api               0.1.322
# easydict                      1.9
# ecos                          2.0.10
# editdistance                  0.5.3
# en-core-web-sm                3.4.0
# entrypoints                   0.4
# ephem                         4.1.3
# et-xmlfile                    1.1.0
# etils                         0.7.1
# etuples                       0.3.5
# fa2                           0.3.5
# fastai                        2.7.9
# fastcore                      1.5.22
# fastdownload                  0.0.7
# fastdtw                       0.3.4
# fastjsonschema                2.16.1
# fastprogress                  1.0.3
# fastrlock                     0.8
# feather-format                0.4.1
# filelock                      3.8.0
# firebase-admin                4.4.0
# fix-yahoo-finance             0.0.22
# Flask                         1.1.4
# flatbuffers                   2.0.7
# folium                        0.12.1.post1
# frozenlist                    1.3.1
# fsspec                        2022.8.1
# future                        0.16.0
# gast                          0.5.3
# GDAL                          2.2.2
# gdown                         4.4.0
# gensim                        3.6.0
# geographiclib                 1.52
# geopy                         1.17.0
# gin-config                    0.5.0
# glob2                         0.7
# google                        2.0.3
# google-api-core               1.31.6
# google-api-python-client      1.12.11
# google-auth                   1.35.0
# google-auth-httplib2          0.0.4
# google-auth-oauthlib          0.4.6
# google-cloud-bigquery         1.21.0
# google-cloud-bigquery-storage 1.1.2
# google-cloud-core             1.0.3
# google-cloud-datastore        1.8.0
# google-cloud-firestore        1.7.0
# google-cloud-language         1.2.0
# google-cloud-storage          1.18.1
# google-cloud-translate        1.5.0
# google-colab                  1.0.0
# google-pasta                  0.2.0
# google-resumable-media        0.4.1
# googleapis-common-protos      1.56.4
# googledrivedownloader         0.4
# graphviz                      0.10.1
# greenlet                      1.1.3
# grpcio                        1.47.0
# gspread                       3.4.2
# gspread-dataframe             3.0.8
# gym                           0.25.2
# gym-notices                   0.0.8
# h5py                          3.1.0
# HeapDict                      1.0.1
# hijri-converter               2.2.4
# holidays                      0.15
# holoviews                     1.14.9
# html5lib                      1.0.1
# httpimport                    0.5.18
# httplib2                      0.17.4
# httplib2shim                  0.0.3
# httpstan                      4.6.1
# humanize                      0.5.1
# hyperopt                      0.1.2
# idna                          2.10
# imageio                       2.9.0
# imagesize                     1.4.1
# imbalanced-learn              0.8.1
# imblearn                      0.0
# imgaug                        0.4.0
# importlib-metadata            4.12.0
# importlib-resources           5.9.0
# imutils                       0.5.4
# inflect                       2.1.0
# intel-openmp                  2022.1.0
# intervaltree                  2.1.0
# ipykernel                     5.3.4
# ipython                       7.9.0
# ipython-genutils              0.2.0
# ipython-sql                   0.3.9
# ipywidgets                    7.7.1
# itsdangerous                  1.1.0
# jax                           0.3.17
# jaxlib                        0.3.15+cuda11.cudnn805
# jieba                         0.42.1
# Jinja2                        2.11.3
# joblib                        1.1.0
# jpeg4py                       0.1.4
# jsonschema                    4.3.3
# jupyter-client                6.1.12
# jupyter-console               6.1.0
# jupyter-core                  4.11.1
# jupyterlab-widgets            3.0.2
# kaggle                        1.5.12
# kapre                         0.3.7
# keras                         2.8.0
# Keras-Preprocessing           1.1.2
# keras-vis                     0.4.1
# kiwisolver                    1.4.4
# korean-lunar-calendar         0.2.1
# langcodes                     3.3.0
# libclang                      14.0.6
# librosa                       0.8.1
# lightgbm                      2.2.3
# llvmlite                      0.39.0
# lmdb                          0.99
# locket                        1.0.0
# logical-unification           0.4.5
# LunarCalendar                 0.0.9
# lxml                          4.9.1
# Markdown                      3.4.1
# MarkupSafe                    2.0.1
# marshmallow                   3.17.1
# matplotlib                    3.2.2
# matplotlib-venn               0.11.7
# miniKanren                    1.0.3
# missingno                     0.5.1
# mistune                       0.8.4
# mizani                        0.7.3
# mkl                           2019.0
# mlxtend                       0.14.0
# more-itertools                8.14.0
# moviepy                       0.2.3.5
# mpmath                        1.2.1
# msgpack                       1.0.4
# multidict                     6.0.2
# multipledispatch              0.6.0
# multitasking                  0.0.11
# murmurhash                    1.0.8
# music21                       5.5.0
# natsort                       5.5.0
# nbconvert                     5.6.1
# nbformat                      5.4.0
# netCDF4                       1.6.0
# networkx                      2.6.3
# nibabel                       3.0.2
# nltk                          3.7
# notebook                      5.3.1
# numba                         0.56.0
# numexpr                       2.8.3
# numpy                         1.21.6
# oauth2client                  4.1.3
# oauthlib                      3.2.0
# okgrade                       0.4.3
# opencv-contrib-python         4.6.0.66
# opencv-python                 4.6.0.66
# opencv-python-headless        4.6.0.66
# openpyxl                      3.0.10
# opt-einsum                    3.3.0
# osqp                          0.6.2.post0
# packaging                     21.3
# palettable                    3.3.0
# pandas                        1.3.5
# pandas-datareader             0.9.0
# pandas-gbq                    0.13.3
# pandas-profiling              1.4.1
# pandocfilters                 1.5.0
# panel                         0.12.1
# param                         1.12.2
# parso                         0.8.3
# partd                         1.3.0
# pastel                        0.2.1
# pathlib                       1.0.1
# pathy                         0.6.2
# patsy                         0.5.2
# pep517                        0.13.0
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        7.1.2
# pip                           21.1.3
# pip-tools                     6.2.0
# plotly                        5.5.0
# plotnine                      0.8.0
# pluggy                        0.7.1
# pooch                         1.6.0
# portpicker                    1.3.9
# prefetch-generator            1.0.1
# preshed                       3.0.7
# prettytable                   3.4.0
# progressbar2                  3.38.0
# promise                       2.3
# prompt-toolkit                2.0.10
# prophet                       1.1
# protobuf                      3.17.3
# psutil                        5.4.8
# psycopg2                      2.9.3
# ptyprocess                    0.7.0
# py                            1.11.0
# pyarrow                       6.0.1
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.4
# pycparser                     2.21
# pyct                          0.4.8
# pydantic                      1.9.2
# pydata-google-auth            1.4.0
# pydot                         1.3.0
# pydot-ng                      2.0.0
# pydotplus                     2.0.2
# PyDrive                       1.3.1
# pyemd                         0.5.1
# pyerfa                        2.0.0.1
# Pygments                      2.6.1
# pygobject                     3.26.1
# pylev                         1.4.0
# pymc                          4.1.4
# PyMeeus                       0.5.11
# pymongo                       4.2.0
# pymystem3                     0.2.0
# PyOpenGL                      3.1.6
# pyparsing                     3.0.9
# pyrsistent                    0.18.1
# pysimdjson                    3.2.0
# pysndfile                     1.3.8
# PySocks                       1.7.1
# pystan                        3.3.0
# pytest                        3.6.4
# python-apt                    0.0.0
# python-chess                  0.23.11
# python-dateutil               2.8.2
# python-louvain                0.16
# python-slugify                6.1.2
# python-utils                  3.3.3
# pytz                          2022.2.1
# pyviz-comms                   2.2.1
# PyWavelets                    1.3.0
# PyYAML                        6.0
# pyzmq                         23.2.1
# qdldl                         0.1.5.post2
# qudida                        0.0.4
# regex                         2022.6.2
# requests                      2.23.0
# requests-oauthlib             1.3.1
# resampy                       0.4.0
# rpy2                          3.4.5
# rsa                           4.9
# scikit-image                  0.18.3
# scikit-learn                  1.0.2
# scipy                         1.7.3
# screen-resolution-extra       0.0.0
# scs                           3.2.0
# seaborn                       0.11.2
# Send2Trash                    1.8.0
# setuptools                    57.4.0
# setuptools-git                1.2
# Shapely                       1.8.4
# six                           1.15.0
# sklearn-pandas                1.8.0
# smart-open                    5.2.1
# snowballstemmer               2.2.0
# sortedcontainers              2.4.0
# SoundFile                     0.10.3.post1
# spacy                         3.4.1
# spacy-legacy                  3.0.10
# spacy-loggers                 1.0.3
# Sphinx                        1.8.6
# sphinxcontrib-serializinghtml 1.1.5
# sphinxcontrib-websupport      1.2.4
# SQLAlchemy                    1.4.40
# sqlparse                      0.4.2
# srsly                         2.4.4
# statsmodels                   0.12.2
# sympy                         1.7.1
# tables                        3.7.0
# tabulate                      0.8.10
# tblib                         1.7.0
# tenacity                      8.0.1
# tensorboard                   2.8.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.8.2+zzzcolab20220719082949
# tensorflow-datasets           4.6.0
# tensorflow-estimator          2.8.0
# tensorflow-gcs-config         2.8.0
# tensorflow-hub                0.12.0
# tensorflow-io-gcs-filesystem  0.26.0
# tensorflow-metadata           1.10.0
# tensorflow-probability        0.16.0
# termcolor                     1.1.0
# terminado                     0.13.3
# testpath                      0.6.0
# text-unidecode                1.3
# textblob                      0.15.3
# thinc                         8.1.0
# threadpoolctl                 3.1.0
# tifffile                      2021.11.2
# toml                          0.10.2
# tomli                         2.0.1
# toolz                         0.12.0
# torch                         1.12.1+cu113
# torchaudio                    0.12.1+cu113
# torchsummary                  1.5.1
# torchtext                     0.13.1
# torchvision                   0.13.1+cu113
# tornado                       5.1.1
# tqdm                          4.64.0
# traitlets                     5.1.1
# tweepy                        3.10.0
# typeguard                     2.7.1
# typer                         0.4.2
# typing-extensions             4.1.1
# tzlocal                       1.5.1
# ujson                         5.4.0
# uritemplate                   3.0.1
# urllib3                       1.24.3
# vega-datasets                 0.9.0
# wasabi                        0.10.1
# wcwidth                       0.2.5
# webargs                       8.2.0
# webencodings                  0.5.1
# Werkzeug                      1.0.1
# wheel                         0.37.1
# widgetsnbextension            3.6.1
# wordcloud                     1.8.2.2
# wrapt                         1.14.1
# xarray                        0.20.2
# xarray-einstats               0.2.2
# xgboost                       0.90
# xkit                          0.0.0
# xlrd                          1.1.0
# xlwt                          1.3.0
# yarl                          1.8.1
# yellowbrick                   1.5
# zict                          2.2.0
# zipp                          3.8.1

# %%
# !pip install flaml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: flaml in /usr/local/lib/python3.7/dist-packages (1.0.12)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.7/dist-packages (from flaml) (1.0.2)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.7/dist-packages (from flaml) (1.3.5)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from flaml) (1.7.3)
# Requirement already satisfied: NumPy>=1.17.0rc1 in /usr/local/lib/python3.7/dist-packages (from flaml) (1.21.6)
# Requirement already satisfied: lightgbm>=2.3.1 in /usr/local/lib/python3.7/dist-packages (from flaml) (3.3.2)
# Requirement already satisfied: xgboost>=0.90 in /usr/local/lib/python3.7/dist-packages (from flaml) (0.90)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm>=2.3.1->flaml) (0.37.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.4->flaml) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.4->flaml) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1.4->flaml) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24->flaml) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24->flaml) (3.1.0)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from flaml import AutoML

# %%
automl = AutoML()
automl_settings={
    'time_budget':800,
    'metric': 'roc_auc',
    'task':  'classification',
    'log_file_name': 'myopia.log'
}

# %%
df = pd.read_csv('../content/reduced_filtered_df.csv')

# %%
df.head(2)
# Out:
#      ACD     LT    VCD  SPORTHR  DADMY  delta_spheq  total_positive_screen  \
# 0  3.702  3.392  15.29        4      1        1.358                      8
# 1  3.462  3.514  15.52       14      0        1.929                     10
#
#    MYOPIC
# 0       0
# 1       0

# %%
X=df.drop('MYOPIC', axis=1)
y=df['MYOPIC']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, stratify=y)

# %% [markdown]
# ## Test AUTOML

# %%
automl.fit(X_train, y_train, **automl_settings)
# Out:
# Streaming output truncated to the last 5000 lines.
# [flaml.automl: 09-07 16:05:44] {3174} INFO - iteration 1273, current learner lgbm
# INFO:flaml.automl:iteration 1273, current learner lgbm
# [flaml.automl: 09-07 16:05:44] {3360} INFO -  at 259.2s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 259.2s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:44] {3174} INFO - iteration 1274, current learner lgbm
# INFO:flaml.automl:iteration 1274, current learner lgbm
# [flaml.automl: 09-07 16:05:45] {3360} INFO -  at 259.3s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 259.3s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:45] {3174} INFO - iteration 1275, current learner xgboost
# INFO:flaml.automl:iteration 1275, current learner xgboost
# [flaml.automl: 09-07 16:05:45] {3360} INFO -  at 259.4s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 259.4s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:45] {3174} INFO - iteration 1276, current learner xgboost
# INFO:flaml.automl:iteration 1276, current learner xgboost
# [flaml.automl: 09-07 16:05:45] {3360} INFO -  at 259.5s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 259.5s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:45] {3174} INFO - iteration 1277, current learner xgboost
# INFO:flaml.automl:iteration 1277, current learner xgboost
# [flaml.automl: 09-07 16:05:45] {3360} INFO -  at 259.6s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 259.6s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:45] {3174} INFO - iteration 1278, current learner lgbm
# INFO:flaml.automl:iteration 1278, current learner lgbm
# [flaml.automl: 09-07 16:05:45] {3360} INFO -  at 259.7s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 259.7s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:45] {3174} INFO - iteration 1279, current learner xgboost
# INFO:flaml.automl:iteration 1279, current learner xgboost
# [flaml.automl: 09-07 16:05:45] {3360} INFO -  at 259.9s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 259.9s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:45] {3174} INFO - iteration 1280, current learner xgboost
# INFO:flaml.automl:iteration 1280, current learner xgboost
# [flaml.automl: 09-07 16:05:45] {3360} INFO -  at 260.0s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 260.0s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:45] {3174} INFO - iteration 1281, current learner rf
# INFO:flaml.automl:iteration 1281, current learner rf
# [flaml.automl: 09-07 16:05:47] {3360} INFO -  at 261.3s,	estimator rf's best error=0.1137,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 261.3s,	estimator rf's best error=0.1137,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:47] {3174} INFO - iteration 1282, current learner lgbm
# INFO:flaml.automl:iteration 1282, current learner lgbm
# [flaml.automl: 09-07 16:05:47] {3360} INFO -  at 261.4s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 261.4s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:47] {3174} INFO - iteration 1283, current learner lgbm
# INFO:flaml.automl:iteration 1283, current learner lgbm
# [flaml.automl: 09-07 16:05:47] {3360} INFO -  at 261.5s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 261.5s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:47] {3174} INFO - iteration 1284, current learner lgbm
# INFO:flaml.automl:iteration 1284, current learner lgbm
# [flaml.automl: 09-07 16:05:47] {3360} INFO -  at 261.7s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 261.7s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:47] {3174} INFO - iteration 1285, current learner lgbm
# INFO:flaml.automl:iteration 1285, current learner lgbm
# [flaml.automl: 09-07 16:05:47] {3360} INFO -  at 261.8s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 261.8s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:47] {3174} INFO - iteration 1286, current learner xgboost
# INFO:flaml.automl:iteration 1286, current learner xgboost
# [flaml.automl: 09-07 16:05:47] {3360} INFO -  at 261.9s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 261.9s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:47] {3174} INFO - iteration 1287, current learner xgboost
# INFO:flaml.automl:iteration 1287, current learner xgboost
# [flaml.automl: 09-07 16:05:47] {3360} INFO -  at 262.0s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 262.0s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:47] {3174} INFO - iteration 1288, current learner xgboost
# INFO:flaml.automl:iteration 1288, current learner xgboost
# [flaml.automl: 09-07 16:05:47] {3360} INFO -  at 262.1s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 262.1s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:47] {3174} INFO - iteration 1289, current learner lgbm
# INFO:flaml.automl:iteration 1289, current learner lgbm
# [flaml.automl: 09-07 16:05:48] {3360} INFO -  at 262.3s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 262.3s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:48] {3174} INFO - iteration 1290, current learner xgboost
# INFO:flaml.automl:iteration 1290, current learner xgboost
# [flaml.automl: 09-07 16:05:48] {3360} INFO -  at 262.4s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 262.4s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:48] {3174} INFO - iteration 1291, current learner xgboost
# INFO:flaml.automl:iteration 1291, current learner xgboost
# [flaml.automl: 09-07 16:05:48] {3360} INFO -  at 262.5s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 262.5s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:48] {3174} INFO - iteration 1292, current learner lgbm
# INFO:flaml.automl:iteration 1292, current learner lgbm
# [flaml.automl: 09-07 16:05:48] {3360} INFO -  at 262.6s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 262.6s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:48] {3174} INFO - iteration 1293, current learner lgbm
# INFO:flaml.automl:iteration 1293, current learner lgbm
# [flaml.automl: 09-07 16:05:48] {3360} INFO -  at 262.7s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 262.7s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:48] {3174} INFO - iteration 1294, current learner lgbm
# INFO:flaml.automl:iteration 1294, current learner lgbm
# [flaml.automl: 09-07 16:05:48] {3360} INFO -  at 262.9s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 262.9s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:48] {3174} INFO - iteration 1295, current learner xgboost
# INFO:flaml.automl:iteration 1295, current learner xgboost
# [flaml.automl: 09-07 16:05:48] {3360} INFO -  at 263.0s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 263.0s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:48] {3174} INFO - iteration 1296, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 1296, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:05:48] {3360} INFO -  at 263.1s,	estimator xgb_limitdepth's best error=0.1147,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 263.1s,	estimator xgb_limitdepth's best error=0.1147,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:48] {3174} INFO - iteration 1297, current learner extra_tree
# INFO:flaml.automl:iteration 1297, current learner extra_tree
# [flaml.automl: 09-07 16:05:50] {3360} INFO -  at 264.4s,	estimator extra_tree's best error=0.1409,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 264.4s,	estimator extra_tree's best error=0.1409,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:50] {3174} INFO - iteration 1298, current learner xgboost
# INFO:flaml.automl:iteration 1298, current learner xgboost
# [flaml.automl: 09-07 16:05:50] {3360} INFO -  at 264.5s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 264.5s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:50] {3174} INFO - iteration 1299, current learner extra_tree
# INFO:flaml.automl:iteration 1299, current learner extra_tree
# [flaml.automl: 09-07 16:05:51] {3360} INFO -  at 265.8s,	estimator extra_tree's best error=0.1409,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 265.8s,	estimator extra_tree's best error=0.1409,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:51] {3174} INFO - iteration 1300, current learner xgboost
# INFO:flaml.automl:iteration 1300, current learner xgboost
# [flaml.automl: 09-07 16:05:51] {3360} INFO -  at 265.9s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 265.9s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:51] {3174} INFO - iteration 1301, current learner extra_tree
# INFO:flaml.automl:iteration 1301, current learner extra_tree
# [flaml.automl: 09-07 16:05:53] {3360} INFO -  at 267.4s,	estimator extra_tree's best error=0.1191,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 267.4s,	estimator extra_tree's best error=0.1191,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05:53] {3174} INFO - iteration 1302, current learner extra_tree
# INFO:flaml.automl:iteration 1302, current learner extra_tree
# [flaml.automl: 09-07 16:05:54] {3360} INFO -  at 268.7s,	estimator extra_tree's best error=0.1191,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 268.7s,	estimator extra_tree's best error=0.1191,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:05
,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 289.0s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06:14] {3174} INFO - iteration 1338, current learner lgbm
# INFO:flaml.automl:iteration 1338, current learner lgbm
# [flaml.automl: 09-07 16:06:14] {3360} INFO -  at 289.1s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 289.1s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06:14] {3174} INFO - iteration 1339, current learner xgboost
# INFO:flaml.automl:iteration 1339, current learner xgboost
# [flaml.automl: 09-07 16:06:14] {3360} INFO -  at 289.2s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 289.2s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06:14] {3174} INFO - iteration 1340, current learner xgboost
# INFO:flaml.automl:iteration 1340, current learner xgboost
# [flaml.automl: 09-07 16:06:15] {3360} INFO -  at 289.3s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 289.3s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06:15] {3174} INFO - iteration 1341, current learner xgboost
# INFO:flaml.automl:iteration 1341, current learner xgboost
# [flaml.automl: 09-07 16:06:15] {3360} INFO -  at 289.5s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 289.5s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06:15] {3174} INFO - iteration 1342, current learner xgboost
# INFO:flaml.automl:iteration 1342, current learner xgboost
# [flaml.automl: 09-07 16:06:15] {3360} INFO -  at 289.6s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 289.6s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06:15] {3174} INFO - iteration 1343, current learner xgboost
# INFO:flaml.automl:iteration 1343, current learner xgboost
# [flaml.automl: 09-07 16:06:15] {3360} INFO -  at 289.7s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 289.7s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06:15] {3174} INFO - iteration 1344, current learner xgboost
# INFO:flaml.automl:iteration 1344, current learner xgboost
# [flaml.automl: 09-07 16:06:15] {3360} INFO -  at 289.8s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 289.8s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06:15] {3174} INFO - iteration 1345, current learner extra_tree
# INFO:flaml.automl:iteration 1345, current learner extra_tree
# [flaml.automl: 09-07 16:06:17] {3360} INFO -  at 291.3s,	estimator extra_tree's best error=0.1191,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 291.3s,	estimator extra_tree's best error=0.1191,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06:17] {3174} INFO - iteration 1346, current learner extra_tree
# INFO:flaml.automl:iteration 1346, current learner extra_tree
# [flaml.automl: 09-07 16:06:18] {3360} INFO -  at 292.6s,	estimator extra_tree's best error=0.1191,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 292.6s,	estimator extra_tree's best error=0.1191,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06:18] {3174} INFO - iteration 1347, current learner extra_tree
# INFO:flaml.automl:iteration 1347, current learner extra_tree
# [flaml.automl: 09-07 16:06:19] {3360} INFO -  at 293.9s,	estimator extra_tree's best error=0.1191,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 293.9s,	estimator extra_tree's best error=0.1191,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06:19] {3174} INFO - iteration 1348, current learner xgboost
# INFO:flaml.automl:iteration 1348, current learner xgboost
# [flaml.automl: 09-07 16:06:19] {3360} INFO -  at 294.0s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 294.0s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06:19] {3174} INFO - iteration 1349, current learner xgboost
# INFO:flaml.automl:iteration 1349, current learner xgboost
# [flaml.automl: 09-07 16:06:19] {3360} INFO -  at 294.1s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 294.1s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06:19] {3174} INFO - iteration 1350, current learner xgboost
# INFO:flaml.automl:iteration 1350, current learner xgboost
# [flaml.automl: 09-07 16:06:20] {3360} INFO -  at 294.3s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 294.3s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06:20] {3174} INFO - iteration 1351, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 1351, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:06:20] {3360} INFO -  at 294.4s,	estimator xgb_limitdepth's best error=0.1147,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 294.4s,	estimator xgb_limitdepth's best error=0.1147,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06:20] {3174} INFO - iteration 1352, current learner xgboost
# INFO:flaml.automl:iteration 1352, current learner xgboost
# [flaml.automl: 09-07 16:06:20] {3360} INFO -  at 294.5s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 294.5s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06:20] {3174} INFO - iteration 1353, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 1353, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:06:20] {3360} INFO -  at 294.7s,	estimator xgb_limitdepth's best error=0.1147,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 294.7s,	estimator xgb_limitdepth's best error=0.1147,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06:20] {3174} INFO - iteration 1354, current learner xgboost
# INFO:flaml.automl:iteration 1354, current learner xgboost
# [flaml.automl: 09-07 16:06:20] {3360} INFO -  at 294.8s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 294.8s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06
,	estimator extra_tree's best error=0.1191,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 312.5s,	estimator extra_tree's best error=0.1191,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06:38] {3174} INFO - iteration 1390, current learner xgboost
# INFO:flaml.automl:iteration 1390, current learner xgboost
# [flaml.automl: 09-07 16:06:38] {3360} INFO -  at 312.6s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 312.6s,	estimator xgboost's best error=0.1051,	best estimator xgboost's best error=0.1051
# [flaml.automl: 09-07 16:06:38] {3174} INFO - iteration 1391, current learner lgbm
# INFO:flaml.automl:iteration 1391, current learner lgbm
# [flaml.automl: 09-07 16:06:38] {3360} INFO -  at 312.7s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# INFO:flaml.automl: at 312.7s,	estimator lgbm's best error=0.1074,	best estimator xgboost's best error=0.1051
# ...
# [flaml.automl: 09-07 16:14:28] {3174} INFO - iteration 2457, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2457, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:28] {3360} INFO -  at 782.7s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 782.7s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:28] {3174} INFO - iteration 2458, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2458, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:28] {3360} INFO -  at 782.9s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 782.9s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:28] {3174} INFO - iteration 2459, current learner extra_tree
# INFO:flaml.automl:iteration 2459, current learner extra_tree
# [flaml.automl: 09-07 16:14:29] {3360} INFO -  at 784.2s,	estimator extra_tree's best error=0.0976,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 784.2s,	estimator extra_tree's best error=0.0976,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:29] {3174} INFO - iteration 2460, current learner extra_tree
# INFO:flaml.automl:iteration 2460, current learner extra_tree
# [flaml.automl: 09-07 16:14:31] {3360} INFO -  at 785.5s,	estimator extra_tree's best error=0.0976,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 785.5s,	estimator extra_tree's best error=0.0976,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:31] {3174} INFO - iteration 2461, current learner extra_tree
# INFO:flaml.automl:iteration 2461, current learner extra_tree
# [flaml.automl: 09-07 16:14:32] {3360} INFO -  at 786.9s,	estimator extra_tree's best error=0.0976,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 786.9s,	estimator extra_tree's best error=0.0976,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:32] {3174} INFO - iteration 2462, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2462, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:32] {3360} INFO -  at 787.1s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 787.1s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:32] {3174} INFO - iteration 2463, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2463, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:32] {3360} INFO -  at 787.2s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 787.2s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:32] {3174} INFO - iteration 2464, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2464, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:33] {3360} INFO -  at 787.3s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 787.3s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:33] {3174} INFO - iteration 2465, current learner extra_tree
# INFO:flaml.automl:iteration 2465, current learner extra_tree
# [flaml.automl: 09-07 16:14:34] {3360} INFO -  at 788.6s,	estimator extra_tree's best error=0.0976,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 788.6s,	estimator extra_tree's best error=0.0976,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:34] {3174} INFO - iteration 2466, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2466, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:34] {3360} INFO -  at 788.8s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 788.8s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:34] {3174} INFO - iteration 2467, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2467, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:34] {3360} INFO -  at 788.9s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 788.9s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:34] {3174} INFO - iteration 2468, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2468, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:34] {3360} INFO -  at 789.1s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 789.1s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:34] {3174} INFO - iteration 2469, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2469, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:34] {3360} INFO -  at 789.2s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 789.2s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:34] {3174} INFO - iteration 2470, current learner xgboost
# INFO:flaml.automl:iteration 2470, current learner xgboost
# [flaml.automl: 09-07 16:14:35] {3360} INFO -  at 789.3s,	estimator xgboost's best error=0.1051,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 789.3s,	estimator xgboost's best error=0.1051,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:35] {3174} INFO - iteration 2471, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2471, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:35] {3360} INFO -  at 789.5s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 789.5s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:35] {3174} INFO - iteration 2472, current learner rf
# INFO:flaml.automl:iteration 2472, current learner rf
# [flaml.automl: 09-07 16:14:36] {3360} INFO -  at 791.2s,	estimator rf's best error=0.1137,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 791.2s,	estimator rf's best error=0.1137,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:36] {3174} INFO - iteration 2473, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2473, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:37] {3360} INFO -  at 791.3s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 791.3s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:37] {3174} INFO - iteration 2474, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2474, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:37] {3360} INFO -  at 791.4s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 791.4s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:37] {3174} INFO - iteration 2475, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2475, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:37] {3360} INFO -  at 791.6s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 791.6s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:37] {3174} INFO - iteration 2476, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2476, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:37] {3360} INFO -  at 791.7s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 791.7s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:37] {3174} INFO - iteration 2477, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2477, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:37] {3360} INFO -  at 791.9s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 791.9s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:37] {3174} INFO - iteration 2478, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2478, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:37] {3360} INFO -  at 792.0s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 792.0s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:37] {3174} INFO - iteration 2479, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2479, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:37] {3360} INFO -  at 792.1s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 792.1s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:37] {3174} INFO - iteration 2480, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2480, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:38] {3360} INFO -  at 792.3s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 792.3s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:38] {3174} INFO - iteration 2481, current learner extra_tree
# INFO:flaml.automl:iteration 2481, current learner extra_tree
# [flaml.automl: 09-07 16:14:39] {3360} INFO -  at 793.8s,	estimator extra_tree's best error=0.0976,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 793.8s,	estimator extra_tree's best error=0.0976,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:39] {3174} INFO - iteration 2482, current learner extra_tree
# INFO:flaml.automl:iteration 2482, current learner extra_tree
# [flaml.automl: 09-07 16:14:40] {3360} INFO -  at 795.1s,	estimator extra_tree's best error=0.0976,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 795.1s,	estimator extra_tree's best error=0.0976,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:40] {3174} INFO - iteration 2483, current learner extra_tree
# INFO:flaml.automl:iteration 2483, current learner extra_tree
# [flaml.automl: 09-07 16:14:42] {3360} INFO -  at 796.4s,	estimator extra_tree's best error=0.0976,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 796.4s,	estimator extra_tree's best error=0.0976,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:42] {3174} INFO - iteration 2484, current learner extra_tree
# INFO:flaml.automl:iteration 2484, current learner extra_tree
# [flaml.automl: 09-07 16:14:43] {3360} INFO -  at 797.7s,	estimator extra_tree's best error=0.0976,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 797.7s,	estimator extra_tree's best error=0.0976,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:43] {3174} INFO - iteration 2485, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2485, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:43] {3360} INFO -  at 797.8s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 797.8s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:43] {3174} INFO - iteration 2486, current learner lgbm
# INFO:flaml.automl:iteration 2486, current learner lgbm
# [flaml.automl: 09-07 16:14:43] {3360} INFO -  at 798.0s,	estimator lgbm's best error=0.1067,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 798.0s,	estimator lgbm's best error=0.1067,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:43] {3174} INFO - iteration 2487, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2487, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:43] {3360} INFO -  at 798.1s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 798.1s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:43] {3174} INFO - iteration 2488, current learner extra_tree
# INFO:flaml.automl:iteration 2488, current learner extra_tree
# [flaml.automl: 09-07 16:14:45] {3360} INFO -  at 799.4s,	estimator extra_tree's best error=0.0976,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 799.4s,	estimator extra_tree's best error=0.0976,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:45] {3174} INFO - iteration 2489, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2489, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:45] {3360} INFO -  at 799.5s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 799.5s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:45] {3174} INFO - iteration 2490, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2490, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:45] {3360} INFO -  at 799.7s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 799.7s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:45] {3174} INFO - iteration 2491, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2491, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:45] {3360} INFO -  at 799.8s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 799.8s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:45] {3174} INFO - iteration 2492, current learner xgb_limitdepth
# INFO:flaml.automl:iteration 2492, current learner xgb_limitdepth
# [flaml.automl: 09-07 16:14:45] {3360} INFO -  at 799.9s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# INFO:flaml.automl: at 799.9s,	estimator xgb_limitdepth's best error=0.1016,	best estimator extra_tree's best error=0.0976
# [flaml.automl: 09-07 16:14:46] {3620} INFO - retrain extra_tree for 0.3s
# INFO:flaml.automl:retrain extra_tree for 0.3s
# [flaml.automl: 09-07 16:14:46] {3625} INFO - retrained model: ExtraTreesClassifier(criterion='entropy', max_features=0.8256461243349812,
#                      max_leaf_nodes=6, n_estimators=8, n_jobs=-1)
# INFO:flaml.automl:retrained model: ExtraTreesClassifier(criterion='entropy', max_features=0.8256461243349812,
#                      max_leaf_nodes=6, n_estimators=8, n_jobs=-1)
# [flaml.automl: 09-07 16:14:46] {2900} INFO - fit succeeded
# INFO:flaml.automl:fit succeeded
# [flaml.automl: 09-07 16:14:46] {2902} INFO - Time taken to find the best model: 548.0488455295563
# INFO:flaml.automl:Time taken to find the best model: 548.0488455295563

# %%
print(automl.model)
# Out:
# <flaml.model.ExtraTreesEstimator object at 0x7efdd070c5d0>

# %%
automl.best_estimator
# Out:
# 'extra_tree'

# %%
print(f"Best Loss:  {automl.best_loss_per_estimator['xgboost']}")
xgb_params = automl.best_config_per_estimator['xgboost']
xgb_params
# Out:
# Best Loss:  0.10512861394557824
# {'n_estimators': 13,
#  'max_leaves': 7,
#  'min_child_weight': 4.335302249239383,
#  'learning_rate': 0.2586916043984912,
#  'subsample': 0.6107563495205902,
#  'colsample_bylevel': 1.0,
#  'colsample_bytree': 0.8667840140423164,
#  'reg_alpha': 0.08918943610851687,
#  'reg_lambda': 0.08977890903450676}

# %%
print(f"Best Loss:  {automl.best_loss_per_estimator['extra_tree']}")
et_params = automl.best_config_per_estimator['extra_tree']
et_params
# Out:
# Best Loss:  0.09757121598639451
# {'n_estimators': 8,
#  'max_leaves': 6,
#  'max_features': 0.8256461243349812,
#  'criterion': 'entropy'}

# %%
print(f"Best Loss:  {automl.best_loss_per_estimator['rf']}")
rf_params = automl.best_config_per_estimator['rf']
rf_params
# Out:
# Best Loss:  0.11372767857142863
# {'n_estimators': 7,
#  'max_features': 0.740603165778064,
#  'max_leaves': 6,
#  'criterion': 'gini'}

# %%
# Here is how the models compared
automl.best_loss_per_estimator
# Out:
# {'lgbm': 0.10673666788143825,
#  'rf': 0.11372767857142863,
#  'xgboost': 0.10512861394557824,
#  'extra_tree': 0.09757121598639451,
#  'xgb_limitdepth': 0.10159742468415936,
#  'lrl1': 0.14579689018464528}

# %%
print('Best ML leaner:', automl.best_estimator)
print('Best hyperparmeter config:', automl.best_config)
print('Best accuracy on validation data: {0:.4g}'.format(1-automl.best_loss))
print('Training duration of best run: {0:.4g} s'.format(automl.best_config_train_time))
# Out:
# Best ML leaner: extra_tree
# Best hyperparmeter config: {'n_estimators': 8, 'max_leaves': 6, 'max_features': 0.8256461243349812, 'criterion': 'entropy'}
# Best accuracy on validation data: 0.9024
# Training duration of best run: 0.3296 s

# %% [markdown]
# ## Test the XGBoost with Params

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score

# %%
clf = XGBClassifier()
clf.set_params(**xgb_params)
scores = cross_val_score(clf, X_train, y_train, scoring='precision')

# %%
np.mean(scores)
# Out:
# 0.6666666666666666

# %%
clf.get_params()
# Out:
# {'base_score': 0.5,
#  'booster': 'gbtree',
#  'colsample_bylevel': 1.0,
#  'colsample_bynode': 1,
#  'colsample_bytree': 0.8667840140423164,
#  'gamma': 0,
#  'learning_rate': 0.2586916043984912,
#  'max_delta_step': 0,
#  'max_depth': 3,
#  'min_child_weight': 4.335302249239383,
#  'missing': None,
#  'n_estimators': 13,
#  'n_jobs': 1,
#  'nthread': None,
#  'objective': 'binary:logistic',
#  'random_state': 0,
#  'reg_alpha': 0.08918943610851687,
#  'reg_lambda': 0.08977890903450676,
#  'scale_pos_weight': 1,
#  'seed': None,
#  'silent': None,
#  'subsample': 0.6107563495205902,
#  'verbosity': 1,
#  'max_leaves': 7}

# %%
clf.fit(X,y)
y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92        81
#            1       0.43      0.25      0.32        12
#
#     accuracy                           0.86        93
#    macro avg       0.66      0.60      0.62        93
# weighted avg       0.84      0.86      0.84        93
