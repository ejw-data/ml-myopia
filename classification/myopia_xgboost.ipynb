# %% [markdown]
# # myopia_xgboost.ipynb

# %%
# Initial imports

# ignore metric did not predict warning
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display, HTML

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statistics import mean, mode
from pathlib import Path
from imblearn.pipeline import Pipeline
# from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold, StratifiedKFold, GridSearchCV, cross_val_score, cross_validate, validation_curve
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from imblearn.over_sampling import SMOTE  
from binary_classifier import model_compare

# %%
df = pd.read_csv('../eda/reduced_filtered_df.csv')

# %%
df.head(2)
# Out:
#      ACD     LT    VCD  SPORTHR  DADMY  delta_spheq  total_positive_screen  \
# 0  3.702  3.392  15.29        4      1        1.358                      8
# 1  3.462  3.514  15.52       14      0        1.929                     10
#
#    MYOPIC
# 0       0
# 1       0

# %%
X=df.drop('MYOPIC', axis=1)
y=df['MYOPIC']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, stratify=y)

# %% [markdown]
# ## Test the XGBoost with Params

# %%
from xgboost import XGBClassifier

# %%
params = {'n_estimators': 7,
 'max_leaves': 6,
 'min_child_weight': 5.8614537300277965,
 'learning_rate': 0.11677765280016518,
 'subsample': 0.8895588746662894,
 'colsample_bylevel': 0.7905358317292889,
 'colsample_bytree': 0.9544060556215052,
 'reg_alpha': 0.0015245843735931766,
 'reg_lambda': 0.5536296597037936}

# %%
clf = XGBClassifier()
clf.set_params(**params)
# Out:
# XGBClassifier(base_score=None, booster=None,
#               colsample_bylevel=0.7905358317292889, colsample_bynode=None,
#               colsample_bytree=0.9544060556215052, gamma=None, gpu_id=None,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.11677765280016518, max_delta_step=None,
#               max_depth=None, max_leaves=6, min_child_weight=5.8614537300277965,
#               missing=nan, monotone_constraints=None, n_estimators=7,
#               n_jobs=None, num_parallel_tree=None, random_state=None,
#               reg_alpha=0.0015245843735931766, reg_lambda=0.5536296597037936,
#               scale_pos_weight=None, subsample=0.8895588746662894,
#               tree_method=None, validate_parameters=None, verbosity=None)

# %%
# create process steps
pipes = [
    ("scaler", StandardScaler()),
    ("xgboost", clf)
]

# target labels
labels=['not_myopic', 'myopic']

# 5 fold cross validation
cv = StratifiedKFold(n_splits=5)


summary_dict = model_compare('XGBoost', X_train, y_train, X_test, y_test, labels, pipes, cv)
# Out:
#   scenario              type             pipe1  \
# 0  XGBoost  cross_validation  StandardScaler()
#
#                                                pipe2 pipe3 pipe4 pipe5  \
# 0  XGBClassifier(base_score=None, booster=None,\n...
#
#                                                   cv  f1-score  recall  \
# 0  StratifiedKFold(n_splits=5, random_state=None,...       0.0     0.0
#
#    precision   ROC_AUC  Precision_Recall_AUC  accuracy
# 0        0.0  0.836681                  0.35  0.867403

# %%
pd.DataFrame(summary_dict)
# Out:
#   scenario               type             pipe1  \
# 0  XGBoost  threshold_train_0  StandardScaler()
# 1  XGBoost  threshold_train_1  StandardScaler()
# 2  XGBoost   threshold_test_0  StandardScaler()
# 3  XGBoost   threshold_test_1  StandardScaler()
# 4  XGBoost   cross_validation  StandardScaler()
#
#                                                pipe2 pipe3 pipe4 pipe5  \
# 0  XGBClassifier(base_score=None, booster=None,\n...
# 1  XGBClassifier(base_score=None, booster=None,\n...
# 2  XGBClassifier(base_score=None, booster=None,\n...
# 3  XGBClassifier(base_score=None, booster=None,\n...
# 4  XGBClassifier(base_score=None, booster=None,\n...
#
#    precision  recall  f1-score  number_samples  accuracy  \
# 0   0.867384     1.0  0.928983           242.0  0.867384
# 1   0.000000     0.0  0.000000            37.0  0.867384
# 2   0.870968     1.0  0.931034            81.0  0.870968
# 3   0.000000     0.0  0.000000            12.0  0.870968
# 4   0.000000     0.0  0.000000             NaN  0.867403
#
#                                                   cv   ROC_AUC  \
# 0                                                NaN       NaN
# 1                                                NaN       NaN
# 2                                                NaN       NaN
# 3                                                NaN       NaN
# 4  StratifiedKFold(n_splits=5, random_state=None,...  0.836681
#
#    Precision_Recall_AUC
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                  0.35
